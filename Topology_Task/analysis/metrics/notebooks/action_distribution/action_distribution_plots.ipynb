# %% [markdown]
# # Action Distribution Plots
#
# Lean notebook backed by `action_distribution_metrics.py`.

# %%
from pathlib import Path
import importlib
import sys

for candidate in [Path.cwd(), *Path.cwd().parents]:
    helpers = candidate / "helpers"
    repo_helpers = candidate / "Topology_Task" / "analysis" / "metrics" / "helpers"
    if helpers.exists() and (helpers / "action_distribution_metrics.py").exists():
        sys.path.insert(0, str(helpers))
        break
    if repo_helpers.exists() and (repo_helpers / "action_distribution_metrics.py").exists():
        sys.path.insert(0, str(repo_helpers))
        break
else:
    raise FileNotFoundError("Could not locate Topology_Task/analysis/metrics/helpers")

import action_distribution_metrics as adm
adm = importlib.reload(adm)
import wandb_metrics as wm
wm = importlib.reload(wm)
print("action_distribution_metrics:", adm.__file__)
print("wandb_metrics:", wm.__file__)
# Out:
# action_distribution_metrics: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/analysis/metrics/helpers/action_distribution_metrics.py
# wandb_metrics: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/analysis/metrics/helpers/wandb_metrics.py

# %% [markdown]
# ## Choose Runs To Load Or Download

# %%
import importlib
wm = importlib.reload(wm)

# Pick config folder(s) under Topology_Task/configs, or use None / "None" / "all" for every run.
# Examples:
# CONFIG_FOLDERS_TO_DOWNLOAD = "intervention_gate_15"
# CONFIG_FOLDERS_TO_DOWNLOAD = ["intervention_gate_15", "phase4_sparse_control_16"]
# CONFIG_FOLDERS_TO_DOWNLOAD = "intervention_gate_15,phase4_sparse_control_16"
# CONFIG_FOLDERS_TO_DOWNLOAD = "all"
CONFIG_FOLDERS_TO_DOWNLOAD = [
    "intervention_gate_15",
    "phase4_sparse_control_16",
    "heuristic_vs_gate_s0_s1_s2",
    "adaptive_intervention_budget_7",
    "adaptive_intervention_budget_mechanism_15",
]

# False only reads local cached histories. True downloads missing matching histories from W&B.
DOWNLOAD_MISSING_FROM_WANDB = False

# Useful when W&B has newer data than the local cache, especially for old scan_history fallback caches.
# This only has an effect when DOWNLOAD_MISSING_FROM_WANDB is True.
REFRESH_SCAN_HISTORY_FALLBACKS = False

# Heavier option: replace every selected local cache from W&B.
FORCE_REFRESH_CACHE = False

wm.configure_run_filter_from_config_folder(CONFIG_FOLDERS_TO_DOWNLOAD)
wm.EXCLUDE_RUN_NAME_REGEX = None
wm.RUN_STATES = None
wm.MAX_RUNS = None
wm.USE_LOCAL_CACHE_ONLY = not DOWNLOAD_MISSING_FROM_WANDB
wm.REFRESH_SCAN_HISTORY_FALLBACKS = bool(DOWNLOAD_MISSING_FROM_WANDB and REFRESH_SCAN_HISTORY_FALLBACKS)
wm.FORCE_REFRESH = bool(DOWNLOAD_MISSING_FROM_WANDB and FORCE_REFRESH_CACHE)
wm.ALLOW_SCAN_HISTORY_FALLBACK = True
wm.refresh_run_filters()

print("RUN_NAME_REGEX =", wm.RUN_NAME_REGEX)
print("USE_LOCAL_CACHE_ONLY =", wm.USE_LOCAL_CACHE_ONLY)
print("REFRESH_SCAN_HISTORY_FALLBACKS =", wm.REFRESH_SCAN_HISTORY_FALLBACKS)
print("FORCE_REFRESH =", wm.FORCE_REFRESH)
# Out:
# Config folder filter:
#   - /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/configs/intervention_gate_15
#   - /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/configs/phase4_sparse_control_16
#   - /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/configs/heuristic_vs_gate_s0_s1_s2
#   - /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/configs/adaptive_intervention_budget_7
#   - /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/configs/adaptive_intervention_budget_mechanism_15
# Matched config run-name candidates: 84
# RUN_NAME_REGEX = ^\s*(?:ig_00_phase2_base_s0|ig_00_phase2_base_s1|ig_00_phase2_base_s2|ig_01_entropy_decay_s0|ig_01_entropy_decay_s1|ig_01_entropy_decay_s2|ig_02_topo001_entropy_decay_s0|ig_02_topo001_entropy_decay_s1|ig_02_topo001_entropy_decay_s2|ig_03_topo005_entropy_decay_s0|ig_03_topo005_entropy_decay_s1|ig_03_topo005_entropy_decay_s2|ig_04_topo010_entropy_decay_s0|ig_04_topo010_entropy_decay_s1|ig_04_topo010_entropy_decay_s2|sparse16_flat_p000_s0|sparse16_flat_p000_s1|sparse16_flat_p000_s2|sparse16_flat_p001_s0|sparse16_flat_p001_s1|sparse16_flat_p001_s2|sparse16_flat_p003_s0|sparse16_flat_p003_s1|sparse16_flat_p003_s2|sparse16_flat_p010_s0|sparse16_flat_p010_s1|sparse16_flat_p010_s2|sparse16_gated_p000_s0|sparse16_gated_p000_s1|sparse16_gated_p000_s2|sparse16_gated_p001_s0|sparse16_gated_p001_s1|sparse16_gated_p001_s2|sparse16_gated_p003_s0|sparse16_gated_p003_s1|sparse16_gated_p003_s2|sparse16_gated_p010_s0|sparse16_gated_p010_s1|sparse16_gated_p010_s2|hvg_00_baseline_s0|hvg_00_baseline_s1|hvg_00_baseline_s2|hvg_01_eval_rho090_s0|hvg_01_eval_rho090_s1|hvg_01_eval_rho090_s2|hvg_02_gate_final_map_s0|hvg_02_gate_final_map_s1|hvg_02_gate_final_map_s2|hvg_03_gate_hierarchical_s0|hvg_03_gate_hierarchical_s1|hvg_03_gate_hierarchical_s2|hvg_04_eval_local_rho090_s0|hvg_04_eval_local_rho090_s1|hvg_04_eval_local_rho090_s2|aib_00_flat_local_t020_s0|aib_00_flat_local_t020_s1|aib_00_flat_local_t020_s2|aib_01_flat_local_t010_s0|aib_01_flat_local_t010_s1|aib_01_flat_local_t010_s2|aib_02_flat_local_t035_s0|aib_02_flat_local_t035_s1|aib_02_flat_local_t035_s2|aib_03_gate_hgreedy_sep_local_t020_s0|aib_03_gate_hgreedy_sep_local_t020_s1|aib_03_gate_hgreedy_sep_local_t020_s2|aib_04_flat_nonidle_t020_s0|aib_04_flat_nonidle_t020_s1|aib_04_flat_nonidle_t020_s2|aibm_00_fixed_nonidle_p006_s0|aibm_00_fixed_nonidle_p006_s1|aibm_00_fixed_nonidle_p006_s2|aibm_01_fixed_global_safe_p006_s0|aibm_01_fixed_global_safe_p006_s1|aibm_01_fixed_global_safe_p006_s2|aibm_02_adaptive_global_t020_s0|aibm_02_adaptive_global_t020_s1|aibm_02_adaptive_global_t020_s2|aibm_03_adaptive_local_t020_r085_s0|aibm_03_adaptive_local_t020_r085_s1|aibm_03_adaptive_local_t020_r085_s2|aibm_04_adaptive_local_t020_r095_s0|aibm_04_adaptive_local_t020_r095_s1|aibm_04_adaptive_local_t020_r095_s2)\s*$
# USE_LOCAL_CACHE_ONLY = True
# REFRESH_SCAN_HISTORY_FALLBACKS = False
# FORCE_REFRESH = False

# %% [markdown]
# ## Load Or Download Selected W&B Histories

# %%
download_data = wm.load_wandb_data()
downloaded_runs_df = download_data.runs_df
print(f"Matching W&B runs: {len(downloaded_runs_df)}")
# Out:
# Project: corentin-plumet-epfl/Grid2Op
# Task dir: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task
# Cache mode: full
# Cache dir: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache
# Local-only mode: True
# Force refresh: False
# Refresh scan-history fallbacks: False
# Selected 84 cached runs from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history
# state
# finished    69
# crashed     15
# History artifact setup: local_only=True, runs_df=84
# [ 1/84] loading artifact cache: aib_00_flat_local_t020_s0
#     loaded 278 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_00_flat_local_t020_s0__MAPPO_bus14_T_0_0__I__1781866679_28407/history.parquet in 0.2s
# [ 2/84] loading artifact cache: aib_00_flat_local_t020_s1
#     loaded 328 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_00_flat_local_t020_s1__MAPPO_bus14_T_1_0__I__1781866694_49730/history.parquet in 0.0s
# [ 3/84] loading artifact cache: aib_00_flat_local_t020_s2
#     loaded 318 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_00_flat_local_t020_s2__MAPPO_bus14_T_2_0__I__1781866774_22965/history.parquet in 0.0s
# [ 4/84] loading artifact cache: aib_01_flat_local_t010_s0
#     loaded 336 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_01_flat_local_t010_s0__MAPPO_bus14_T_0_0__I__1781866739_33185/history.parquet in 0.0s
# [ 5/84] loading artifact cache: aib_01_flat_local_t010_s1
#     loaded 306 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_01_flat_local_t010_s1__MAPPO_bus14_T_1_0__I__1781976538_41170/history.parquet in 0.0s
# [ 6/84] loading artifact cache: aib_01_flat_local_t010_s2
#     loaded 314 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_01_flat_local_t010_s2__MAPPO_bus14_T_2_0__I__1781976578_26129/history.parquet in 0.0s
# [ 7/84] loading artifact cache: aib_02_flat_local_t035_s0
#     loaded 302 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_02_flat_local_t035_s0__MAPPO_bus14_T_0_0__I__1781866806_46137/history.parquet in 0.0s
# [ 8/84] loading artifact cache: aib_02_flat_local_t035_s1
#     loaded 264 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_02_flat_local_t035_s1__MAPPO_bus14_T_1_0__I__1781866739_44059/history.parquet in 0.0s
# [ 9/84] loading artifact cache: aib_02_flat_local_t035_s2
#     loaded 375 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_02_flat_local_t035_s2__MAPPO_bus14_T_2_0__I__1781976539_9054/history.parquet in 0.0s
# [10/84] loading artifact cache: aib_03_gate_hgreedy_sep_local_t020_s0
#     loaded 375 rows, 170 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_03_gate_hgreedy_sep_local_t020_s0__MAPPO_bus14_T_0_0__I__1781866679_34311/history.parquet in 0.0s
# [11/84] loading artifact cache: aib_03_gate_hgreedy_sep_local_t020_s1
#     loaded 375 rows, 170 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_03_gate_hgreedy_sep_local_t020_s1__MAPPO_bus14_T_1_0__I__1781976455_45314/history.parquet in 0.0s
# [12/84] loading artifact cache: aib_03_gate_hgreedy_sep_local_t020_s2
#     loaded 375 rows, 170 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_03_gate_hgreedy_sep_local_t020_s2__MAPPO_bus14_T_2_0__I__1781976540_14420/history.parquet in 0.0s
# [13/84] loading artifact cache: aib_04_flat_nonidle_t020_s0
#     loaded 375 rows, 137 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_04_flat_nonidle_t020_s0__MAPPO_bus14_T_0_0__I__1781976538_18683/history.parquet in 0.0s
# [14/84] loading artifact cache: aib_04_flat_nonidle_t020_s1
#     loaded 310 rows, 137 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_04_flat_nonidle_t020_s1__MAPPO_bus14_T_1_0__I__1781976472_18953/history.parquet in 0.0s
# [15/84] loading artifact cache: aib_04_flat_nonidle_t020_s2
#     loaded 325 rows, 137 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aib_04_flat_nonidle_t020_s2__MAPPO_bus14_T_2_0__I__1781976436_14920/history.parquet in 0.0s
# [16/84] loading artifact cache: aibm_00_fixed_nonidle_p006_s0
#     loaded 332 rows, 111 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_00_fixed_nonidle_p006_s0__MAPPO_bus14_T_0_0__I__1782064745_26214/history.parquet in 0.0s
# [17/84] loading artifact cache: aibm_00_fixed_nonidle_p006_s1
#     loaded 330 rows, 111 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_00_fixed_nonidle_p006_s1__MAPPO_bus14_T_1_0__I__1782064745_21130/history.parquet in 0.0s
# [18/84] loading artifact cache: aibm_00_fixed_nonidle_p006_s2
#     loaded 324 rows, 111 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_00_fixed_nonidle_p006_s2__MAPPO_bus14_T_2_0__I__1782064745_35864/history.parquet in 0.0s
# [19/84] loading artifact cache: aibm_01_fixed_global_safe_p006_s0
#     loaded 306 rows, 118 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_01_fixed_global_safe_p006_s0__MAPPO_bus14_T_0_0__I__1782064745_10603/history.parquet in 0.0s
# [20/84] loading artifact cache: aibm_01_fixed_global_safe_p006_s1
#     loaded 320 rows, 118 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_01_fixed_global_safe_p006_s1__MAPPO_bus14_T_1_0__I__1782064745_36442/history.parquet in 0.0s
# [21/84] loading artifact cache: aibm_01_fixed_global_safe_p006_s2
#     loaded 324 rows, 118 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_01_fixed_global_safe_p006_s2__MAPPO_bus14_T_2_0__I__1782064745_29097/history.parquet in 0.0s
# [22/84] loading artifact cache: aibm_02_adaptive_global_t020_s0
#     loaded 332 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_02_adaptive_global_t020_s0__MAPPO_bus14_T_0_0__I__1782064745_10648/history.parquet in 0.0s
# [23/84] loading artifact cache: aibm_02_adaptive_global_t020_s1
#     loaded 294 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_02_adaptive_global_t020_s1__MAPPO_bus14_T_1_0__I__1782064745_14137/history.parquet in 0.0s
# [24/84] loading artifact cache: aibm_02_adaptive_global_t020_s2
#     loaded 336 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_02_adaptive_global_t020_s2__MAPPO_bus14_T_2_0__I__1782064745_27146/history.parquet in 0.0s
# [25/84] loading artifact cache: aibm_03_adaptive_local_t020_r085_s0
#     loaded 353 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_03_adaptive_local_t020_r085_s0__MAPPO_bus14_T_0_0__I__1782064745_37996/history.parquet in 0.0s
# [26/84] loading artifact cache: aibm_03_adaptive_local_t020_r085_s1
#     loaded 370 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_03_adaptive_local_t020_r085_s1__MAPPO_bus14_T_1_0__I__1782064745_36022/history.parquet in 0.0s
# [27/84] loading artifact cache: aibm_03_adaptive_local_t020_r085_s2
#     loaded 368 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_03_adaptive_local_t020_r085_s2__MAPPO_bus14_T_2_0__I__1782064745_20856/history.parquet in 0.0s
# [28/84] loading artifact cache: aibm_04_adaptive_local_t020_r095_s0
#     loaded 358 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_04_adaptive_local_t020_r095_s0__MAPPO_bus14_T_0_0__I__1782064745_10585/history.parquet in 0.0s
# [29/84] loading artifact cache: aibm_04_adaptive_local_t020_r095_s1
#     loaded 324 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_04_adaptive_local_t020_r095_s1__MAPPO_bus14_T_1_0__I__1782064745_10065/history.parquet in 0.0s
# [30/84] loading artifact cache: aibm_04_adaptive_local_t020_r095_s2
#     loaded 312 rows, 140 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/aibm_04_adaptive_local_t020_r095_s2__MAPPO_bus14_T_2_0__I__1782064745_14121/history.parquet in 0.0s
# [31/84] loading artifact cache: hvg_00_baseline_s0
#     loaded 288 rows, 97 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_00_baseline_s0__MAPPO_bus14_T_0_0__I__1781776044_11513/history.parquet in 0.0s
# [32/84] loading artifact cache: hvg_00_baseline_s1
#     loaded 253 rows, 97 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_00_baseline_s1__MAPPO_bus14_T_1_0__I__1781776044_15259/history.parquet in 0.0s
# [33/84] loading artifact cache: hvg_00_baseline_s2
#     loaded 292 rows, 97 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_00_baseline_s2__MAPPO_bus14_T_2_0__I__1781776044_31010/history.parquet in 0.0s
# [34/84] loading artifact cache: hvg_01_eval_rho090_s0
#     loaded 286 rows, 115 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_01_eval_rho090_s0__MAPPO_bus14_T_0_0__I__1781776044_33979/history.parquet in 0.0s
# [35/84] loading artifact cache: hvg_01_eval_rho090_s1
#     loaded 252 rows, 115 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_01_eval_rho090_s1__MAPPO_bus14_T_1_0__I__1781776044_33468/history.parquet in 0.0s
# [36/84] loading artifact cache: hvg_01_eval_rho090_s2
#     loaded 284 rows, 115 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_01_eval_rho090_s2__MAPPO_bus14_T_2_0__I__1781776044_5653/history.parquet in 0.0s
# [37/84] loading artifact cache: hvg_02_gate_final_map_s0
#     loaded 266 rows, 124 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_02_gate_final_map_s0__MAPPO_bus14_T_0_0__I__1781776043_6909/history.parquet in 0.0s
# [38/84] loading artifact cache: hvg_02_gate_final_map_s1
#     loaded 324 rows, 124 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_02_gate_final_map_s1__MAPPO_bus14_T_1_0__I__1781776044_39515/history.parquet in 0.1s
# [39/84] loading artifact cache: hvg_02_gate_final_map_s2
#     loaded 227 rows, 124 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_02_gate_final_map_s2__MAPPO_bus14_T_2_0__I__1781776044_27085/history.parquet in 0.0s
# [40/84] loading artifact cache: hvg_03_gate_hierarchical_s0
#     loaded 266 rows, 124 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_03_gate_hierarchical_s0__MAPPO_bus14_T_0_0__I__1781776043_11435/history.parquet in 0.0s
# [41/84] loading artifact cache: hvg_03_gate_hierarchical_s1
#     loaded 313 rows, 124 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_03_gate_hierarchical_s1__MAPPO_bus14_T_1_0__I__1781776044_47655/history.parquet in 0.0s
# [42/84] loading artifact cache: hvg_03_gate_hierarchical_s2
#     loaded 226 rows, 124 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_03_gate_hierarchical_s2__MAPPO_bus14_T_2_0__I__1781776044_26454/history.parquet in 0.0s
# [43/84] loading artifact cache: hvg_04_eval_local_rho090_s0
#     loaded 290 rows, 133 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_04_eval_local_rho090_s0__MAPPO_bus14_T_0_0__I__1781843990_27364/history.parquet in 0.0s
# [44/84] loading artifact cache: hvg_04_eval_local_rho090_s1
#     loaded 254 rows, 133 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_04_eval_local_rho090_s1__MAPPO_bus14_T_1_0__I__1781843972_13542/history.parquet in 0.0s
# [45/84] loading artifact cache: hvg_04_eval_local_rho090_s2
#     loaded 306 rows, 133 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/hvg_04_eval_local_rho090_s2__MAPPO_bus14_T_2_0__I__1781843990_38484/history.parquet in 0.0s
# [46/84] loading artifact cache: ig_00_phase2_base_s0
#     loaded 101 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_00_phase2_base_s0__MAPPO_bus14_T_0_0__I__1781599604_40819/history.parquet in 0.0s
# [47/84] loading artifact cache: ig_00_phase2_base_s1
#     loaded 129 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_00_phase2_base_s1__MAPPO_bus14_T_1_0__I__1781599604_2719/history.parquet in 0.0s
# [48/84] loading artifact cache: ig_00_phase2_base_s2
#     loaded 91 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_00_phase2_base_s2__MAPPO_bus14_T_2_0__I__1781599604_24783/history.parquet in 0.0s
# [49/84] loading artifact cache: ig_01_entropy_decay_s0
#     loaded 126 rows, 85 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_01_entropy_decay_s0__MAPPO_bus14_T_0_0__I__1781599604_10745/history.parquet in 0.0s
# [50/84] loading artifact cache: ig_01_entropy_decay_s1
#     loaded 118 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_01_entropy_decay_s1__MAPPO_bus14_T_1_0__I__1781599604_8912/history.parquet in 0.0s
# [51/84] loading artifact cache: ig_01_entropy_decay_s2
#     loaded 101 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_01_entropy_decay_s2__MAPPO_bus14_T_2_0__I__1781599604_47490/history.parquet in 0.0s
# [52/84] loading artifact cache: ig_02_topo001_entropy_decay_s0
#     loaded 113 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_02_topo001_entropy_decay_s0__MAPPO_bus14_T_0_0__I__1781599605_24167/history.parquet in 0.0s
# [53/84] loading artifact cache: ig_02_topo001_entropy_decay_s1
#     loaded 128 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_02_topo001_entropy_decay_s1__MAPPO_bus14_T_1_0__I__1781599605_39667/history.parquet in 0.0s
# [54/84] loading artifact cache: ig_02_topo001_entropy_decay_s2
#     loaded 125 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_02_topo001_entropy_decay_s2__MAPPO_bus14_T_2_0__I__1781599604_5627/history.parquet in 0.0s
# [55/84] loading artifact cache: ig_03_topo005_entropy_decay_s0
#     loaded 99 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_03_topo005_entropy_decay_s0__MAPPO_bus14_T_0_0__I__1781599604_14309/history.parquet in 0.0s
# [56/84] loading artifact cache: ig_03_topo005_entropy_decay_s1
#     loaded 115 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_03_topo005_entropy_decay_s1__MAPPO_bus14_T_1_0__I__1781599604_35601/history.parquet in 0.0s
# [57/84] loading artifact cache: ig_03_topo005_entropy_decay_s2
#     loaded 113 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_03_topo005_entropy_decay_s2__MAPPO_bus14_T_2_0__I__1781599604_11364/history.parquet in 0.0s
# [58/84] loading artifact cache: ig_04_topo010_entropy_decay_s0
#     loaded 119 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_04_topo010_entropy_decay_s0__MAPPO_bus14_T_0_0__I__1781599604_2506/history.parquet in 0.0s
# [59/84] loading artifact cache: ig_04_topo010_entropy_decay_s1
#     loaded 117 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_04_topo010_entropy_decay_s1__MAPPO_bus14_T_1_0__I__1781599604_22257/history.parquet in 0.0s
# [60/84] loading artifact cache: ig_04_topo010_entropy_decay_s2
#     loaded 119 rows, 82 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/ig_04_topo010_entropy_decay_s2__MAPPO_bus14_T_2_0__I__1781599604_23740/history.parquet in 0.0s
# [61/84] loading artifact cache: sparse16_flat_p000_s0
#     loaded 288 rows, 97 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p000_s0__MAPPO_bus14_T_0_0__I__1781691854_36156/history.parquet in 0.0s
# [62/84] loading artifact cache: sparse16_flat_p000_s1
#     loaded 254 rows, 97 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p000_s1__MAPPO_bus14_T_1_0__I__1781627028_12475/history.parquet in 0.0s
# [63/84] loading artifact cache: sparse16_flat_p000_s2
#     loaded 290 rows, 103 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p000_s2__MAPPO_bus14_T_2_0__I__1781975275_49914/history.parquet in 0.0s
# [64/84] loading artifact cache: sparse16_flat_p001_s0
#     loaded 266 rows, 105 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p001_s0__MAPPO_bus14_T_0_0__I__1781626962_27067/history.parquet in 0.0s
# [65/84] loading artifact cache: sparse16_flat_p001_s1
#     loaded 304 rows, 105 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p001_s1__MAPPO_bus14_T_1_0__I__1781692835_34095/history.parquet in 0.0s
# [66/84] loading artifact cache: sparse16_flat_p001_s2
#     loaded 308 rows, 111 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p001_s2__MAPPO_bus14_T_2_0__I__1781975275_38809/history.parquet in 0.0s
# [67/84] loading artifact cache: sparse16_flat_p003_s0
#     loaded 288 rows, 105 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p003_s0__MAPPO_bus14_T_0_0__I__1781626967_24444/history.parquet in 0.0s
# [68/84] loading artifact cache: sparse16_flat_p003_s1
#     loaded 314 rows, 105 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p003_s1__MAPPO_bus14_T_1_0__I__1781692602_3968/history.parquet in 0.0s
# [69/84] loading artifact cache: sparse16_flat_p003_s2
#     loaded 322 rows, 111 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p003_s2__MAPPO_bus14_T_2_0__I__1781975275_34022/history.parquet in 0.0s
# [70/84] loading artifact cache: sparse16_flat_p010_s0
#     loaded 297 rows, 105 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p010_s0__MAPPO_bus14_T_0_0__I__1781626907_18955/history.parquet in 0.0s
# [71/84] loading artifact cache: sparse16_flat_p010_s1
#     loaded 320 rows, 105 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p010_s1__MAPPO_bus14_T_1_0__I__1781626890_20616/history.parquet in 0.0s
# [72/84] loading artifact cache: sparse16_flat_p010_s2
#     loaded 282 rows, 111 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_flat_p010_s2__MAPPO_bus14_T_2_0__I__1781975275_32766/history.parquet in 0.0s
# [73/84] loading artifact cache: sparse16_gated_p000_s0
#     loaded 266 rows, 124 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p000_s0__MAPPO_bus14_T_0_0__I__1781626907_21232/history.parquet in 0.0s
# [74/84] loading artifact cache: sparse16_gated_p000_s1
#     loaded 325 rows, 124 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p000_s1__MAPPO_bus14_T_1_0__I__1781626900_4209/history.parquet in 0.1s
# [75/84] loading artifact cache: sparse16_gated_p000_s2
#     loaded 228 rows, 133 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p000_s2__MAPPO_bus14_T_2_0__I__1781975275_15323/history.parquet in 0.0s
# [76/84] loading artifact cache: sparse16_gated_p001_s0
#     loaded 298 rows, 132 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p001_s0__MAPPO_bus14_T_0_0__I__1781691854_22251/history.parquet in 0.0s
# [77/84] loading artifact cache: sparse16_gated_p001_s1
#     loaded 298 rows, 132 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p001_s1__MAPPO_bus14_T_1_0__I__1781691854_19240/history.parquet in 0.0s
# [78/84] loading artifact cache: sparse16_gated_p001_s2
#     loaded 270 rows, 141 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p001_s2__MAPPO_bus14_T_2_0__I__1781975275_31955/history.parquet in 0.0s
# [79/84] loading artifact cache: sparse16_gated_p003_s0
#     loaded 261 rows, 132 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p003_s0__MAPPO_bus14_T_0_0__I__1781626958_49869/history.parquet in 0.0s
# [80/84] loading artifact cache: sparse16_gated_p003_s1
#     loaded 266 rows, 132 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p003_s1__MAPPO_bus14_T_1_0__I__1781691854_12607/history.parquet in 0.0s
# [81/84] loading artifact cache: sparse16_gated_p003_s2
#     loaded 280 rows, 141 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p003_s2__MAPPO_bus14_T_2_0__I__1781975275_4662/history.parquet in 0.0s
# [82/84] loading artifact cache: sparse16_gated_p010_s0
#     loaded 310 rows, 132 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p010_s0__MAPPO_bus14_T_0_0__I__1781626890_40020/history.parquet in 0.0s
# [83/84] loading artifact cache: sparse16_gated_p010_s1
#     loaded 352 rows, 132 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p010_s1__MAPPO_bus14_T_1_0__I__1781626939_12428/history.parquet in 0.0s
# [84/84] loading artifact cache: sparse16_gated_p010_s2
#     loaded 280 rows, 141 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history/sparse16_gated_p010_s2__MAPPO_bus14_T_2_0__I__1781975275_28157/history.parquet in 0.0s
# Finished history artifact loading in 2.4s
# Loaded histories for 84 / 84 selected runs
# Saved cache index: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history_cache_index.csv
# (388422, 6)
# Matching W&B runs: 84

# %% [markdown]
# ## Load Cached Histories And Shared Tables

# %%
# Use final evaluation action metrics for the action-distribution plots.
# Set ACTION_METRIC_SOURCE = "train" to reproduce the old rollout-training plots.
ACTION_METRIC_SOURCE = "eval"
EVAL_METRIC_SPLIT = "test"

# Final-window plots average the last logged points at or before this step.
# Use None to treat each run's actual last logged point as final.
FINAL_SUMMARY_STEP_M = None  # Set to None to use each run's actual last logged point.

ctx = adm.load_action_distribution_context(
    action_metric_source=ACTION_METRIC_SOURCE,
    eval_split=EVAL_METRIC_SPLIT,
    final_summary_step_m=FINAL_SUMMARY_STEP_M,
    save_figures=True,
    show_figures=False,
)
# Out:
# Expected configs: 69
# Cached expected runs: 69 / 69
# [  1/69] loading aib_00_flat_local_t020_s0
# [  2/69] loading aib_00_flat_local_t020_s1
# [  3/69] loading aib_00_flat_local_t020_s2
# [  4/69] loading aib_01_flat_local_t010_s0
# [  5/69] loading aib_01_flat_local_t010_s1
# [  6/69] loading aib_01_flat_local_t010_s2
# [  7/69] loading aib_02_flat_local_t035_s0
# [  8/69] loading aib_02_flat_local_t035_s1
# [  9/69] loading aib_02_flat_local_t035_s2
# [ 10/69] loading aib_03_gate_hgreedy_sep_local_t020_s0
# [ 11/69] loading aib_03_gate_hgreedy_sep_local_t020_s1
# [ 12/69] loading aib_03_gate_hgreedy_sep_local_t020_s2
# [ 13/69] loading aib_04_flat_nonidle_t020_s0
# [ 14/69] loading aib_04_flat_nonidle_t020_s1
# [ 15/69] loading aib_04_flat_nonidle_t020_s2
# [ 16/69] loading hvg_00_baseline_s0
# [ 17/69] loading hvg_00_baseline_s1
# [ 18/69] loading hvg_00_baseline_s2
# [ 19/69] loading hvg_01_eval_rho090_s0
# [ 20/69] loading hvg_01_eval_rho090_s1
# [ 21/69] loading hvg_01_eval_rho090_s2
# [ 22/69] loading hvg_02_gate_final_map_s0
# [ 23/69] loading hvg_02_gate_final_map_s1
# [ 24/69] loading hvg_02_gate_final_map_s2
# [ 25/69] loading hvg_03_gate_hierarchical_s0
# [ 26/69] loading hvg_03_gate_hierarchical_s1
# [ 27/69] loading hvg_03_gate_hierarchical_s2
# [ 28/69] loading hvg_04_eval_local_rho090_s0
# [ 29/69] loading hvg_04_eval_local_rho090_s1
# [ 30/69] loading hvg_04_eval_local_rho090_s2
# [ 31/69] loading ig_00_phase2_base_s0
# [ 32/69] loading ig_00_phase2_base_s1
# [ 33/69] loading ig_00_phase2_base_s2
# [ 34/69] loading ig_01_entropy_decay_s0
# [ 35/69] loading ig_01_entropy_decay_s1
# [ 36/69] loading ig_01_entropy_decay_s2
# [ 37/69] loading ig_02_topo001_entropy_decay_s0
# [ 38/69] loading ig_02_topo001_entropy_decay_s1
# [ 39/69] loading ig_02_topo001_entropy_decay_s2
# [ 40/69] loading ig_03_topo005_entropy_decay_s0
# [ 41/69] loading ig_03_topo005_entropy_decay_s1
# [ 42/69] loading ig_03_topo005_entropy_decay_s2
# [ 43/69] loading ig_04_topo010_entropy_decay_s0
# [ 44/69] loading ig_04_topo010_entropy_decay_s1
# [ 45/69] loading ig_04_topo010_entropy_decay_s2
# [ 46/69] loading sparse16_flat_p000_s0
# [ 47/69] loading sparse16_flat_p000_s1
# [ 48/69] loading sparse16_flat_p000_s2
# [ 49/69] loading sparse16_flat_p001_s0
# [ 50/69] loading sparse16_flat_p001_s1
# [ 51/69] loading sparse16_flat_p001_s2
# [ 52/69] loading sparse16_flat_p003_s0
# [ 53/69] loading sparse16_flat_p003_s1
# [ 54/69] loading sparse16_flat_p003_s2
# [ 55/69] loading sparse16_flat_p010_s0
# [ 56/69] loading sparse16_flat_p010_s1
# [ 57/69] loading sparse16_flat_p010_s2
# [ 58/69] loading sparse16_gated_p000_s0
# [ 59/69] loading sparse16_gated_p000_s1
# [ 60/69] loading sparse16_gated_p000_s2
# [ 61/69] loading sparse16_gated_p001_s0
# [ 62/69] loading sparse16_gated_p001_s1
# [ 63/69] loading sparse16_gated_p001_s2
# [ 64/69] loading sparse16_gated_p003_s0
# [ 65/69] loading sparse16_gated_p003_s1
# [ 66/69] loading sparse16_gated_p003_s2
# [ 67/69] loading sparse16_gated_p010_s0
# [ 68/69] loading sparse16_gated_p010_s1
# [ 69/69] loading sparse16_gated_p010_s2
# Loaded history shape: (17764, 234)
# Action metric availability by run:
# Using final evaluation action metrics for action-distribution plots: adaptive_intervention_budget_7/agent_0 from test (2475 rows), adaptive_intervention_budget_7/agent_1 from test (2475 rows), adaptive_intervention_budget_7/agent_2 from test (2475 rows), heuristic_vs_gate_s0_s1_s2/agent_0 from test (2062 rows), heuristic_vs_gate_s0_s1_s2/agent_1 from test (2062 rows), heuristic_vs_gate_s0_s1_s2/agent_2 from test (2062 rows), phase4_sparse_control_16/agent_0 from test (3482 rows), phase4_sparse_control_16/agent_1 from test (3482 rows), phase4_sparse_control_16/agent_2 from test (3482 rows)
# No final evaluation action metrics for: intervention_gate_15

# %% [markdown]
# ## Last-5logged action 0 fraction by run and agent

# %%
last5_action0 = adm.last5_logged_action0_fraction_by_agent_all_runs(ctx)
adm.display_metric_figures(last5_action0)
# Out:
# No final run-aggregated action-0 data for intervention_gate_15
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/action_distribution_figures/eval_test/final_action0_fraction_by_run_all_runs_phase4_sparse_control_16.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/action_distribution_figures/eval_test/final_action0_fraction_by_run_all_runs_heuristic_vs_gate_s0_s1_s2.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/action_distribution_figures/eval_test/final_action0_fraction_by_run_all_runs_adaptive_intervention_budget_7.html

# %% [markdown]
# ## Seed-Aggregated Last-5-Logged Action-0 Fraction By Run And Agent

# %%
seed_action0 = adm.seed_aggregated_last5_logged_action0_fraction_by_agent(ctx)
adm.display_metric_figures(seed_action0)
# Out:
# No seed-aggregated run-level action-0 data for intervention_gate_15
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/action_distribution_figures/eval_test/seed_aggregated_final_action0_fraction_by_run_phase4_sparse_control_16.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/action_distribution_figures/eval_test/seed_aggregated_final_action0_fraction_by_run_heuristic_vs_gate_s0_s1_s2.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/action_distribution_figures/eval_test/seed_aggregated_final_action0_fraction_by_run_adaptive_intervention_budget_7.html

# %% [markdown]
# ## Survival vs Action-0 Over Time

# %%
survival_action = adm.survival_vs_action0_non_idle_over_time(ctx)
adm.display_metric_figures(survival_action)
# Out:
# Missing survival or action-behavior data for intervention_gate_15
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/action_distribution_figures/eval_test/survival_vs_action_behavior_phase4_sparse_control_16.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/action_distribution_figures/eval_test/survival_vs_action_behavior_heuristic_vs_gate_s0_s1_s2.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/action_distribution_figures/eval_test/survival_vs_action_behavior_adaptive_intervention_budget_7.html

# %% [markdown]
# ## Action-0 / Survival Tradeoff

# %%
action0_survival = adm.action0_survival_tradeoff(ctx)
adm.display_metric_figures(action0_survival)

# %% [markdown]
# ## Entropy Collapse vs Action-0 Confidence

# %%
entropy_action0 = adm.entropy_collapse_vs_action0_confidence(ctx)
adm.display_metric_figures(entropy_action0)

# %% [markdown]
# ## Agent Non-Idle Imbalance

# %%
agent_imbalance = adm.agent_non_idle_imbalance(ctx)
adm.display_metric_figures(agent_imbalance)

# %% [markdown]
# ## Joint Action Coordination

# %%
joint_coordination = adm.joint_action_coordination(ctx)
adm.display_metric_figures(joint_coordination)

# %% [markdown]
# ## Gate Probability vs Actual Intervention Fraction

# %%
gate_calibration = adm.gate_probability_vs_actual_intervention_fraction(ctx)
adm.display_metric_figures(gate_calibration)
