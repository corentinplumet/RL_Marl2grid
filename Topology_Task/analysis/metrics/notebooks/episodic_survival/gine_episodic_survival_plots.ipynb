# %% [markdown]
# # W&B Run Plots
#
# This notebook calls the reusable plotting helpers in `wandb_metrics.py`. The plot calls below correspond to the cells marked `#KEEP` in `../wandb_run_plots.ipynb`.
#
# For editable single-figure / multi-subplot comparisons, edit the `*_SUBPLOTS` dictionary directly: each subplot title maps to the runs you want to plot in that subplot, and each run spec controls both the selector and the legend label.

# %%
from pathlib import Path
import importlib
import sys

for candidate in [Path.cwd(), *Path.cwd().parents]:
    helpers = candidate / "helpers"
    repo_helpers = candidate / "Topology_Task" / "analysis" / "metrics" / "helpers"
    if helpers.exists() and (helpers / "wandb_metrics.py").exists():
        sys.path.insert(0, str(helpers))
        break
    if repo_helpers.exists() and (repo_helpers / "wandb_metrics.py").exists():
        sys.path.insert(0, str(repo_helpers))
        break
else:
    raise FileNotFoundError("Could not locate Topology_Task/analysis/metrics/helpers")

import wandb_metrics as wm
wm = importlib.reload(wm)
print("wandb_metrics:", wm.__file__)
# Out:
# wandb_metrics: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/analysis/metrics/helpers/wandb_metrics.py

# %% [markdown]
# ## Load Selected W&B Histories

# %%
data = wm.load_wandb_data()

runs_df = data.runs_df
history_df = data.history_df
# Out:
# Project: corentin-plumet-epfl/Grid2Op
# Task dir: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task
# Cache mode: full
# Cache dir: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache
# Local-only mode: True
# Force refresh: False
# Refresh scan-history fallbacks: False
# Selected 359 cached runs from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_cache/full_history
# state
# finished    245
# crashed     109
# killed        5
# History artifact setup: local_only=True, runs_df=359
# [ 1/359] loading artifact cache: a0_aib_00_flat_local_t020_s0
#     loaded 359 rows, 148 columns from /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/run_data/a0_aib_cpu/runs/a0_aib_00_flat_local_t020_s0__MAPPO_bus14_T_0_0__I__1782784223_20854/history.parquet in 0.2s
# [ 2/359] loading artifact cache: a0_aib_00_flat_local_t020_s0
# ...

# %% [markdown]
# ## Entropy Decay

# %%
entropy_decay_fig = wm.plot_entropy_decay_comparison()
entropy_decay_fig
# Out:
# Plot source folders used to build curves: 2 folder(s), 47 run(s)
#   - /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/run_data/entropy_decay_s0_s1_s2 (22 runs)
#   - /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/run_data/no_entropy_decay_s0_s1_s2 (25 runs)

# %% [markdown]
# ## GINE Best Search 2
#
# `gine_best2_fig` is built from the editable `GINE_BEST2_SUBPLOTS` dictionary below. The new default baseline is `rerun_a0_opt_s*`, displayed as `A0_baseline`. The first subplot compares this new baseline against the old GINE `best_00` baseline.

# %%
A0_BASELINE_SPEC = {
    "prefix": "rerun_a0_opt_s",
    "label": "A0_baseline",
    "color": "#1f77b4",
    "width": 4,
}
ANCIENT_GINE_BASELINE_SPEC = {
    "prefix": "best_00_shared_actor_gnn_gine_a4_concat_flat_critic_gnn_legacy_update_s",
    "label": "ancient_GINE_baseline",
    "color": "#ff7f0e",
}

# Edit this dictionary to decide, for each subplot, which runs are plotted and
# how they are named in the legend. Supported selectors: name, prefix, regex,
# contains, runs, run_dir. The legend text is controlled by label.
GINE_BEST2_SUBPLOTS = {
    "A0 baseline vs GINE baseline": [
        A0_BASELINE_SPEC,
        ANCIENT_GINE_BASELINE_SPEC,
    ],
    "A0 baseline vs 000 no concat-flat": [
        A0_BASELINE_SPEC,
        {
            "prefix": "best_000_shared_actor_gnn_gine_a4_no_concat_flat_critic_gnn_legacy_update_s",
            "label": "000_no_concat_flat",
            "color": "#ff7f0e",
        },
    ],
    "A0 baseline vs 01 optimized critic update": [
        A0_BASELINE_SPEC,
        {
            "prefix": "best_01_shared_actor_gnn_gine_a4_concat_flat_critic_gnn_optcritic_s",
            "label": "01_optimized_critic_update",
            "color": "#ff7f0e",
        },
    ],
    "A0 baseline vs 02 MLP critic": [
        A0_BASELINE_SPEC,
        {
            "prefix": "best_02_shared_actor_gnn_gine_a4_concat_flat_critic_mlp_legacy_update_s",
            "label": "02_MLP_critic",
            "color": "#ff7f0e",
        },
    ],
    "A0 baseline vs 03 non-shared actor GNN": [
        A0_BASELINE_SPEC,
        {
            "prefix": "best_03_nonshared_actor_gnn_gine_a4_concat_flat_critic_gnn_legacy_update_s",
            "label": "03_nonshared_actor_GNN",
            "color": "#ff7f0e",
        },
    ],
    "A0 baseline vs 04 light GINE": [
        A0_BASELINE_SPEC,
        {
            "prefix": "best_04_shared_actor_gnn_light_gine_a4_concat_flat_critic_gnn_legacy_update_s",
            "label": "04_light_GINE",
            "color": "#ff7f0e",
        },
    ],
    "A0 baseline vs 05 entropy decay": [
        A0_BASELINE_SPEC,
        {
            "prefix": "best_05_shared_actor_gnn_gine_a4_entropy_decay_concat_flat_critic_gnn_legacy_update_s",
            "label": "05_entropy_decay",
            "color": "#ff7f0e",
        },
    ],
    "A0 baseline vs 06 no node ID": [
        A0_BASELINE_SPEC,
        {
            "prefix": "best_06_shared_actor_gnn_gine_a4_no_node_id_concat_flat_critic_gnn_legacy_update_s",
            "label": "06_no_node_ID",
            "color": "#ff7f0e",
        },
    ],
    "A0 baseline vs 07 GAT": [
        A0_BASELINE_SPEC,
        {
            "prefix": "best_07_shared_actor_gnn_gat_a4_concat_flat_critic_gnn_legacy_update_s",
            "label": "07_GAT",
            "color": "#ff7f0e",
        },
    ],
    "A0 baseline vs 08 weighted GCN": [
        A0_BASELINE_SPEC,
        {
            "prefix": "best_08_shared_actor_gnn_weighted_gcn_a4_concat_flat_critic_gnn_legacy_update_s",
            "label": "08_weighted_GCN",
            "color": "#ff7f0e",
        },
    ],
    "A0 baseline vs 09 light no-concat MLP critic": [
        A0_BASELINE_SPEC,
        {
            "prefix": "best_09_shared_actor_gnn_light_gine_a4_no_concat_flat_critic_mlp_optcritic_s",
            "label": "09_light_no_concat_MLP_critic",
            "color": "#ff7f0e",
        },
    ],
    "A0 baseline vs 10 light concat MLP critic": [
        A0_BASELINE_SPEC,
        {
            "prefix": "best_10_shared_actor_gnn_light_gine_a4_concat_flat_critic_mlp_optcritic_s",
            "label": "10_light_concat_MLP_critic",
            "color": "#ff7f0e",
        },
    ],
}

GINE_BEST2_MEAN_GROUPS = {
    title: wm.resolve_named_plot_specs(run_specs, history=history_df)
    for title, run_specs in GINE_BEST2_SUBPLOTS.items()
}
GINE_BEST2_MEAN_GROUPS = {
    title: specs
    for title, specs in GINE_BEST2_MEAN_GROUPS.items()
    if len(specs) >= 2
}

gine_best2_fig = wm.plot_run_mean_groups(
    GINE_BEST2_MEAN_GROUPS,
    split="test",
    smooth=5,
    title="GINE search: editable comparisons with A0_baseline",
    title_font_size=28,
    subplot_title_font_size=30,
    ncols=4,
    subplot_height=500,
    width=3400,
    y_range=[0, 105],
    show_members=True,
    show_std=True,
    save_name="gine_best_search2_a0_baseline_editable_comparisons",
    history=history_df,
    horizontal_spacing=0.035,
    vertical_spacing=0.045,
    margin={"l": 50, "r": 20, "t": 60, "b": 45},
)
gine_best2_fig
# Out:
# Plot source folders used to build curves: 2 folder(s), 42 run(s)
#   - /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/run_data/a0_test_rerun (3 runs)
#   - /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/run_data/gine_s0_s1_s2 (39 runs)
# Saved plot: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_figures/gine_best_search2_a0_baseline_editable_comparisons.html

# %% [markdown]
# ## Heuristic vs Gate

# %%
hvg_result = wm.plot_heuristic_vs_gate_survival()
hvg_result["fig"]
# Out:
# heuristic_vs_gate_s0_s1_s2 cache coverage: 0/15 runs cached
# No cached episodic survival data for heuristic_vs_gate_s0_s1_s2 yet.
# Download with RUN_NAME_REGEX = '^hvg_(?:00_baseline|01_eval_rho090|02_gate_final_map|03_gate_hierarchical|04_eval_local_rho090)_s[0-2]$'

# %% [markdown]
# ## Phase4 Sparse Control 16

# %%
phase4_sparse_result = wm.plot_phase4_sparse_control_16_survival()
phase4_sparse_result["fig"]
# Out:
# phase4_sparse_control_16 cache coverage: 0/24 runs cached
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 phase4_sparse_result = wm.plot_phase4_sparse_control_16_survival()
#       2 phase4_sparse_result["fig"]
#
# File ~/Documents/RL_Marl2grid/Topology_Task/analysis/metrics/helpers/wandb_metrics.py:5336, in plot_phase4_sparse_control_16_survival()
#    5328 print(
#    5329     f"phase4_sparse_control_16 cache coverage: "
#    5330     f"{int(PHASE4_SPARSE_COVERAGE['cache_exists'].sum())}/{len(PHASE4_SPARSE_COVERAGE)} runs cached"
#    5331 )
#    5332 # display(PHASE4_SPARSE_COVERAGE[[
#    5333 #     "expected_run_name", "condition_label", "seed", "cache_status", "rows", "id",
#    5334 # ]])
# -> 5336 PHASE4_SPARSE_SURVIVAL_FIG = phase4_sparse_plot_survival_baseline_comparisons(
#    5337     PHASE4_SPARSE_SURVIVAL_LONG,
# ...

# %% [markdown]
# ## Adaptive Intervention Budget 7

# %%
AIB_BASELINE_SOURCE = "gine_best2"  # options: "gine_best2", "hvg", "phase4_sparse"
aib_result = wm.plot_adaptive_intervention_budget_7_comparisons(baseline_source=AIB_BASELINE_SOURCE)
aib_result["fig"]
# Out:
# Saved plot: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_figures/adaptive_intervention_budget_7_vs_gine_best2.html

# %% [markdown]
# ## Adaptive Intervention Budget Mechanism 15

# %%
from IPython.display import display

aibm_result = wm.plot_adaptive_intervention_budget_mechanism_15()
for fig in [aibm_result["survival_fig"], aibm_result["diagnostic_fig"]]:
    if fig is not None:
        display(fig)
# Out:
# Saved plot: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_figures/adaptive_intervention_budget_mechanism_15_survival_ablations.html
# Saved plot: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/wandb_figures/adaptive_intervention_budget_mechanism_15_diagnostics.html

# %% [markdown]
# ## GINE Include Neighbors

# %%
gine_neighbor_result = wm.plot_gine_neighbors_vs_original()
gine_neighbor_result["fig"]
# Out:
# Unresolved config runs. These are usually runs that are not downloaded yet, or W&B names/exp_tags collide without config metadata.
# Skipping 04 light GINE: missing one side of the comparison.
# Skipping 05 entropy decay: missing one side of the comparison.
# Skipping 06 no node ID: missing one side of the comparison.
# Skipping 07 GAT: missing one side of the comparison.
# Skipping 08 weighted GCN: missing one side of the comparison.
# Skipping best 09 shared actor gnn light gine a4 no concat flat critic mlp optcritic: missing one side of the comparison.
# Skipping best 10 shared actor gnn light gine a4 concat flat critic mlp optcritic: missing one side of the comparison.
# Skipping best 11 shared actor gnn gine a4 concat flat critic gnn legacy update initbias0: missing one side of the comparison.
# Skipping best 12 shared actor gnn gine a4 concat flat critic gnn opt initbias0: missing one side of the comparison.
# ...
