# %% [markdown]
# # Teacher-Student Comparison Dashboard
#
# This notebook focuses on the teacher-student pipeline:
#
# - teacher dataset size and chronic coverage,
# - teacher action-0 / non-idle balance,
# - heuristic overwrite and force-noop rates,
# - behavior-cloning training curves stored inside student checkpoints,
# - student predicted non-idle rate vs teacher target non-idle rate,
# - standalone full-test JSON summaries for student checkpoints.
#
# It focuses on teacher-dataset summaries, student BC checkpoints, and full-test evaluation outputs.

# %%
from pathlib import Path
import importlib
import sys

for candidate in [Path.cwd(), *Path.cwd().parents]:
    helpers = candidate / "helpers"
    repo_helpers = candidate / "Topology_Task" / "analysis" / "metrics" / "helpers"
    if helpers.exists() and (helpers / "comparison_dashboard.py").exists():
        sys.path.insert(0, str(helpers))
        break
    if repo_helpers.exists() and (repo_helpers / "comparison_dashboard.py").exists():
        sys.path.insert(0, str(repo_helpers))
        break
else:
    raise FileNotFoundError("Could not locate Topology_Task/analysis/metrics/helpers")

import comparison_dashboard as cd
cd = importlib.reload(cd)
print("comparison_dashboard:", cd.__file__)
print("TASK_DIR:", cd.TASK_DIR)
# Out:
# comparison_dashboard: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/analysis/metrics/helpers/comparison_dashboard.py
# TASK_DIR: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task

# %% [markdown]
# ## Configuration

# %%
DATASET_ROOT = cd.TEACHER_DATASET_ROOT
STUDENT_CHECKPOINT_DIR = cd.TEACHER_STUDENT_CHECKPOINT_DIR
SHOW_FIGURES = True
SAVE_FIGURES = True

print("Dataset root:", DATASET_ROOT)
print("Student checkpoint dir:", STUDENT_CHECKPOINT_DIR)
# Out:
# Dataset root: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/teacher_student_datasets
# Student checkpoint dir: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/checkpoint/teacher_student

# %% [markdown]
# ## Teacher Dataset Summaries

# %%
dataset_df, dataset_agent_df = cd.load_teacher_dataset_summaries(DATASET_ROOT)
print("datasets:", len(dataset_df))
display(dataset_df.sort_values("dataset") if not dataset_df.empty else dataset_df)
print("agent summaries:")
display(dataset_agent_df.sort_values(["dataset", "agent"]) if not dataset_agent_df.empty else dataset_agent_df)
cd.plot_teacher_dataset_balance(dataset_agent_df, show=SHOW_FIGURES, save=SAVE_FIGURES)
# Out:
# datasets: 3
#            dataset    bad                                               path  \
# 0  local_rho090_s0  False  /Users/corentinplumet/Documents/RL_Marl2grid/T...
# 1  local_rho090_s1  False  /Users/corentinplumet/Documents/RL_Marl2grid/T...
# 2  local_rho090_s2  False  /Users/corentinplumet/Documents/RL_Marl2grid/T...
#
#                                        metadata_path    status  \
# 0  /Users/corentinplumet/Documents/RL_Marl2grid/T...  complete
# 1  /Users/corentinplumet/Documents/RL_Marl2grid/T...  complete
# 2  /Users/corentinplumet/Documents/RL_Marl2grid/T...  complete
#
#                                           checkpoint  checkpoint_global_step  \
# 0  /home/plumet/RL_Marl2grid/Topology_Task/checkp...                14640000
# 1  /home/plumet/RL_Marl2grid/Topology_Task/checkp...                14480000
# 2  /home/plumet/RL_Marl2grid/Topology_Task/checkp...                15080000
#
#    split eval_action_heuristic  eval_action_rho_threshold  n_env_steps  \
# 0  train   local_rho_threshold                        0.9      5288287
# 1  train   local_rho_threshold                        0.9      6406417
# 2  train   local_rho_threshold                        0.9      5818906
#
#    n_agent_examples  n_completed_episodes  n_unique_chronic_fingerprints  \
# 0          15864861                   803                            803
# 1          19219251                   803                            803
# 2          17456718                   803                            803
#
#    n_shards
# 0       106
# 1       129
# 2       117
# agent summaries:
#            dataset    agent        n  teacher_action0_frac  \
# 0  local_rho090_s0  agent_0  5288287              0.990441
# 1  local_rho090_s0  agent_1  5288287              0.897101
# 2  local_rho090_s0  agent_2  5288287              0.897456
# 3  local_rho090_s1  agent_0  6406417              0.980357
# 4  local_rho090_s1  agent_1  6406417              0.999596
# 5  local_rho090_s1  agent_2  6406417              0.976092
# 6  local_rho090_s2  agent_0  5818906              0.999794
# 7  local_rho090_s2  agent_1  5818906              0.988242
# 8  local_rho090_s2  agent_2  5818906              0.974817
#
#    teacher_nonidle_frac  policy_nonidle_frac  force_noop_frac  \
# 0              0.009559             0.708490         0.987539
# 1              0.102899             0.685626         0.872445
# 2              0.102544             0.790609         0.805782
# 3              0.019643             0.999533         0.980348
# 4              0.000404             0.627844         0.985652
# 5              0.023908             0.586829         0.922090
# 6              0.000206             0.101792         0.989471
# 7              0.011758             0.932946         0.987957
# 8              0.025183             0.756068         0.934108
#
#    was_overwritten_frac  overwrite_to_action0_frac obs_nan_or_inf
# 0              0.698931                   0.698931           None
# 1              0.582727                   0.582727           None
# 2              0.688065                   0.688065           None
# 3              0.979890                   0.979890           None
# 4              0.627440                   0.627440           None
# 5              0.562922                   0.562922           None
# 6              0.101586                   0.101586           None
# 7              0.921188                   0.921188           None
# 8              0.730885                   0.730885           None
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/comparison_dashboard_figures/teacher_dataset_teacher_action0_frac.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/comparison_dashboard_figures/teacher_dataset_teacher_nonidle_frac.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/comparison_dashboard_figures/teacher_dataset_was_overwritten_frac.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/comparison_dashboard_figures/teacher_dataset_force_noop_frac.html
# [Figure({
#      'data': [{'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEHh0aU69KvmP4kJs6ekXe' ... 'AAgIYyVkH0xytCBw+6P855ugmMAbo/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_0<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_0',
#                'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#                'name': 'agent_0',
#                'offsetgroup': 'agent_0',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': 'qDcNbbCx7z9bo425FV/vPzvW8ZhQ/u8/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEGkR5e0pvDlP2KdIdmype' ... 'AAgIYyVkFaBX4usdrtP7w723pfeu0/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_1<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_1',
#                'marker': {'color': '#EF553B', 'pattern': {'shape': ''}},
#                'name': 'agent_1',
#                'offsetgroup': 'agent_1',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': 'vlWKJAy17D9Hh+J3sfzvP2I2XUyun+8/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEGdurFVqkzpP4FyyGqgBO' ... 'AAgIYyVkEhrFdLtTHoP6RCup5pY+c/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_2<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_2',
#                'marker': {'color': '#00cc96', 'pattern': {'shape': ''}},
#                'name': 'agent_2',
#                'offsetgroup': 'agent_2',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': '5bcWFfa37D9sEMzRJTzvP4SWYlO0Me8/', 'dtype': 'f8'},
#                'yaxis': 'y'}],
#      'layout': {'barmode': 'group',
#                 'height': 560,
#                 'legend': {'title': {'text': 'agent'}, 'tracegroupgap': 0},
#                 'template': '...',
#                 'title': {'text': 'Teacher dataset action-0 fraction'},
#                 'width': 1250,
#                 'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'tickangle': -30, 'title': {'text': 'dataset'}},
#                 'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'teacher_action0_frac'}}}
#  }),
#  Figure({
#      'data': [{'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEHh0aU69KvmP4kJs6ekXe' ... 'AAgIYyVkH0xytCBw+6P855ugmMAbo/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_0<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_0',
#                'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#                'name': 'agent_0',
#                'offsetgroup': 'agent_0',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': '6RWyvOSTgz+jlEvOSB2UP6ZKnOJw9io/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEGkR5e0pvDlP2KdIdmype' ... 'AAgIYyVkFaBX4usdrtP7w723pfeu0/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_1<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_1',
#                'marker': {'color': '#EF553B', 'pattern': {'shape': ''}},
#                'name': 'agent_1',
#                'offsetgroup': 'agent_1',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': 'EFKt255Xuj+SxsXrQHQ6P4xnsuhsFIg/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEGdurFVqkzpP4FyyGqgBO' ... 'AAgIYyVkEhrFdLtTHoP6RCup5pY+c/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_2<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_2',
#                'marker': {'color': '#00cc96', 'pattern': {'shape': ''}},
#                'name': 'agent_2',
#                'offsetgroup': 'agent_2',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': '3EBKV09Auj908n3GRXuYP44vrZN1yZk/', 'dtype': 'f8'},
#                'yaxis': 'y'}],
#      'layout': {'barmode': 'group',
#                 'height': 560,
#                 'legend': {'title': {'text': 'agent'}, 'tracegroupgap': 0},
#                 'template': '...',
#                 'title': {'text': 'Teacher dataset non-idle fraction'},
#                 'width': 1250,
#                 'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'tickangle': -30, 'title': {'text': 'dataset'}},
#                 'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'teacher_nonidle_frac'}}}
#  }),
#  Figure({
#      'data': [{'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEHh0aU69KvmP4kJs6ekXe' ... 'AAgIYyVkH0xytCBw+6P855ugmMAbo/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_0<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_0',
#                'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#                'name': 'agent_0',
#                'offsetgroup': 'agent_0',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': 'iQmzp6Rd5j/+FjOiQVvvP855ugmMAbo/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEGkR5e0pvDlP2KdIdmype' ... 'AAgIYyVkFaBX4usdrtP7w723pfeu0/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_1<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_1',
#                'marker': {'color': '#EF553B', 'pattern': {'shape': ''}},
#                'name': 'agent_1',
#                'offsetgroup': 'agent_1',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': 'Yp0h2bKl4j8K/fSc/RPkP7w723pfeu0/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEGdurFVqkzpP4FyyGqgBO' ... 'AAgIYyVkEhrFdLtTHoP6RCup5pY+c/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_2<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_2',
#                'marker': {'color': '#00cc96', 'pattern': {'shape': ''}},
#                'name': 'agent_2',
#                'offsetgroup': 'agent_2',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': 'gXLIaqAE5j+nzwNSdAPiP6RCup5pY+c/', 'dtype': 'f8'},
#                'yaxis': 'y'}],
#      'layout': {'barmode': 'group',
#                 'height': 560,
#                 'legend': {'title': {'text': 'agent'}, 'tracegroupgap': 0},
#                 'template': '...',
#                 'title': {'text': 'Teacher heuristic overwrite fraction'},
#                 'width': 1250,
#                 'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'tickangle': -30, 'title': {'text': 'dataset'}},
#                 'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'was_overwritten_frac'}}}
#  }),
#  Figure({
#      'data': [{'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEHh0aU69KvmP4kJs6ekXe' ... 'AAgIYyVkH0xytCBw+6P855ugmMAbo/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_0<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_0',
#                'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#                'name': 'agent_0',
#                'offsetgroup': 'agent_0',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': 'Hcb/IOuZ7z9oX6NkA1/vP52kAtK+qe8/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEGkR5e0pvDlP2KdIdmype' ... 'AAgIYyVkFaBX4usdrtP7w723pfeu0/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_1<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_1',
#                'marker': {'color': '#EF553B', 'pattern': {'shape': ''}},
#                'name': 'agent_1',
#                'offsetgroup': 'agent_1',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': 'u95JKRHr6z95k3rOdorvP6XA+L9Yne8/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'alignmentgroup': 'True',
#                'customdata': {'bdata': ('AAAAwFcsVEGdurFVqkzpP4FyyGqgBO' ... 'AAgIYyVkEhrFdLtTHoP6RCup5pY+c/'),
#                               'dtype': 'f8',
#                               'shape': '3, 3'},
#                'hovertemplate': ('agent=agent_2<br>dataset=%{x}<' ... '{customdata[2]}<extra></extra>'),
#                'legendgroup': 'agent_2',
#                'marker': {'color': '#00cc96', 'pattern': {'shape': ''}},
#                'name': 'agent_2',
#                'offsetgroup': 'agent_2',
#                'orientation': 'v',
#                'showlegend': True,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array(['local_rho090_s0', 'local_rho090_s1', 'local_rho090_s2'], dtype=object),
#                'xaxis': 'x',
#                'y': {'bdata': 'G77nWfbI6T+w2lI3woHtP3qsipY25O0/', 'dtype': 'f8'},
#                'yaxis': 'y'}],
#      'layout': {'barmode': 'group',
#                 'height': 560,
#                 'legend': {'title': {'text': 'agent'}, 'tracegroupgap': 0},
#                 'template': '...',
#                 'title': {'text': 'Teacher force-noop fraction'},
#                 'width': 1250,
#                 'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'tickangle': -30, 'title': {'text': 'dataset'}},
#                 'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'force_noop_frac'}}}
#  })]

# %% [markdown]
# ## Teacher Dataset Cross-Seed Comparison
#
# This tells you whether the teacher seeds are teaching the same sparse behavior or if each seed specializes different agents.

# %%
if not dataset_agent_df.empty:
    pivot = dataset_agent_df.pivot_table(
        index="dataset",
        columns="agent",
        values=["teacher_action0_frac", "teacher_nonidle_frac", "was_overwritten_frac", "force_noop_frac"],
        aggfunc="mean",
    )
    display(pivot)

    import plotly.express as px
    fig = px.scatter(
        dataset_agent_df,
        x="teacher_nonidle_frac",
        y="was_overwritten_frac",
        color="dataset",
        symbol="agent",
        hover_data=["teacher_action0_frac", "force_noop_frac", "policy_nonidle_frac", "n"],
        labels={
            "teacher_nonidle_frac": "teacher non-idle fraction",
            "was_overwritten_frac": "heuristic overwrite fraction",
        },
        title="Teacher dataset: non-idle target vs heuristic overwrite rate",
    )
    fig.update_layout(template="plotly_white", height=650, width=1050)
    cd.save_fig(fig, "teacher_student_dataset_nonidle_vs_overwrite", save=SAVE_FIGURES)
    if SHOW_FIGURES:
        fig.show()
# Out:
#                 force_noop_frac                     teacher_action0_frac  \
# agent                   agent_0   agent_1   agent_2              agent_0
# dataset
# local_rho090_s0        0.987539  0.872445  0.805782             0.990441
# local_rho090_s1        0.980348  0.985652  0.922090             0.980357
# local_rho090_s2        0.989471  0.987957  0.934108             0.999794
#
#                                     teacher_nonidle_frac                      \
# agent             agent_1   agent_2              agent_0   agent_1   agent_2
# dataset
# local_rho090_s0  0.897101  0.897456             0.009559  0.102899  0.102544
# local_rho090_s1  0.999596  0.976092             0.019643  0.000404  0.023908
# local_rho090_s2  0.988242  0.974817             0.000206  0.011758  0.025183
#
#                 was_overwritten_frac
# agent                        agent_0   agent_1   agent_2
# dataset
# local_rho090_s0             0.698931  0.582727  0.688065
# local_rho090_s1             0.979890  0.627440  0.562922
# local_rho090_s2             0.101586  0.921188  0.730885
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/comparison_dashboard_figures/teacher_student_dataset_nonidle_vs_overwrite.html

# %% [markdown]
# ## Student BC Checkpoint Metrics

# %%
student_ckpt_df, student_epoch_df = cd.load_teacher_student_checkpoints(STUDENT_CHECKPOINT_DIR)
print("student checkpoints:", len(student_ckpt_df))
display(student_ckpt_df.sort_values("checkpoint") if not student_ckpt_df.empty else student_ckpt_df)
print("epoch metrics:")
display(student_epoch_df.sort_values(["checkpoint", "epoch", "phase", "agent"]) if not student_epoch_df.empty else student_epoch_df)
cd.plot_student_bc_metrics(student_epoch_df, show=SHOW_FIGURES, save=SAVE_FIGURES)
# Out:
# student checkpoints: 6
#                          checkpoint  \
# 0  local_bc_bal020_w3_aux025_s0.tar
# 1  local_bc_bal020_w3_aux025_s1.tar
# 2  local_bc_bal020_w3_aux025_s2.tar
# 3                   local_bc_s0.tar
# 4                   local_bc_s1.tar
# 5                   local_bc_s2.tar
#
#                                                 path  global_step  \
# 0  /Users/corentinplumet/Documents/RL_Marl2grid/T...        12375
# 1  /Users/corentinplumet/Documents/RL_Marl2grid/T...        14994
# 2  /Users/corentinplumet/Documents/RL_Marl2grid/T...        13617
# 3  /Users/corentinplumet/Documents/RL_Marl2grid/T...        12375
# 4  /Users/corentinplumet/Documents/RL_Marl2grid/T...        14994
# 5  /Users/corentinplumet/Documents/RL_Marl2grid/T...        13617
#
#            dataset                  teacher_checkpoint  \
# 0  local_rho090_s0  a0_hvg_04_eval_local_rho090_s0.tar
# 1  local_rho090_s1  a0_hvg_04_eval_local_rho090_s1.tar
# 2  local_rho090_s2  a0_hvg_04_eval_local_rho090_s2.tar
# 3  local_rho090_s0  a0_hvg_04_eval_local_rho090_s0.tar
# 4  local_rho090_s1  a0_hvg_04_eval_local_rho090_s1.tar
# 5  local_rho090_s2  a0_hvg_04_eval_local_rho090_s2.tar
#
#    teacher_checkpoint_global_step  epochs  batch_size  balanced_nonidle_frac  \
# 0                        14640000       3        4096                    0.2
# 1                        14480000       3        4096                    0.2
# 2                        15080000       3        4096                    0.2
# 3                        14640000       3        4096                    0.5
# 4                        14480000       3        4096                    0.5
# 5                        15080000       3        4096                    0.5
#
#    nonidle_weight  aux_intervention_loss  aux_weight soft_distillation_loss  \
# 0             3.0                   True        0.25                   None
# 1             3.0                   True        0.25                   None
# 2             3.0                   True        0.25                   None
# 3             5.0                   True        0.50                   None
# 4             5.0                   True        0.50                   None
# 5             5.0                   True        0.50                   None
#
#   soft_weight soft_temperature student_training_objective  \
# 0        None             None                       None
# 1        None             None                       None
# 2        None             None                       None
# 3        None             None                       None
# 4        None             None                       None
# 5        None             None                       None
#
#    dataset_n_env_steps  dataset_n_agent_examples
# 0              5288287                  15864861
# 1              6406417                  19219251
# 2              5818906                  17456718
# 3              5288287                  15864861
# 4              6406417                  19219251
# 5              5818906                  17456718
# epoch metrics:
#                            checkpoint          dataset  epoch  \
# 3    local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      1
# 4    local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      1
# 5    local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      1
# 0    local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      1
# 1    local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      1
# 2    local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      1
# 9    local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      2
# 10   local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      2
# 11   local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      2
# 6    local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      2
# 7    local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      2
# 8    local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      2
# 15   local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      3
# 16   local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      3
# 17   local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      3
# 12   local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      3
# 13   local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      3
# 14   local_bc_bal020_w3_aux025_s0.tar  local_rho090_s0      3
# 21   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      1
# 22   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      1
# 23   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      1
# 18   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      1
# 19   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      1
# 20   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      1
# 27   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      2
# 28   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      2
# 29   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      2
# 24   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      2
# 25   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      2
# 26   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      2
# 33   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      3
# 34   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      3
# 35   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      3
# 30   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      3
# 31   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      3
# 32   local_bc_bal020_w3_aux025_s1.tar  local_rho090_s1      3
# 39   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      1
# 40   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      1
# 41   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      1
# 36   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      1
# 37   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      1
# 38   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      1
# 45   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      2
# 46   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      2
# 47   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      2
# 42   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      2
# 43   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      2
# 44   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      2
# 51   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      3
# 52   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      3
# 53   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      3
# 48   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      3
# 49   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      3
# 50   local_bc_bal020_w3_aux025_s2.tar  local_rho090_s2      3
# 57                    local_bc_s0.tar  local_rho090_s0      1
# 58                    local_bc_s0.tar  local_rho090_s0      1
# 59                    local_bc_s0.tar  local_rho090_s0      1
# 54                    local_bc_s0.tar  local_rho090_s0      1
# 55                    local_bc_s0.tar  local_rho090_s0      1
# 56                    local_bc_s0.tar  local_rho090_s0      1
# 63                    local_bc_s0.tar  local_rho090_s0      2
# 64                    local_bc_s0.tar  local_rho090_s0      2
# 65                    local_bc_s0.tar  local_rho090_s0      2
# 60                    local_bc_s0.tar  local_rho090_s0      2
# 61                    local_bc_s0.tar  local_rho090_s0      2
# 62                    local_bc_s0.tar  local_rho090_s0      2
# 69                    local_bc_s0.tar  local_rho090_s0      3
# 70                    local_bc_s0.tar  local_rho090_s0      3
# 71                    local_bc_s0.tar  local_rho090_s0      3
# 66                    local_bc_s0.tar  local_rho090_s0      3
# 67                    local_bc_s0.tar  local_rho090_s0      3
# 68                    local_bc_s0.tar  local_rho090_s0      3
# 75                    local_bc_s1.tar  local_rho090_s1      1
# 76                    local_bc_s1.tar  local_rho090_s1      1
# 77                    local_bc_s1.tar  local_rho090_s1      1
# 72                    local_bc_s1.tar  local_rho090_s1      1
# 73                    local_bc_s1.tar  local_rho090_s1      1
# 74                    local_bc_s1.tar  local_rho090_s1      1
# 81                    local_bc_s1.tar  local_rho090_s1      2
# 82                    local_bc_s1.tar  local_rho090_s1      2
# 83                    local_bc_s1.tar  local_rho090_s1      2
# 78                    local_bc_s1.tar  local_rho090_s1      2
# 79                    local_bc_s1.tar  local_rho090_s1      2
# 80                    local_bc_s1.tar  local_rho090_s1      2
# 87                    local_bc_s1.tar  local_rho090_s1      3
# 88                    local_bc_s1.tar  local_rho090_s1      3
# 89                    local_bc_s1.tar  local_rho090_s1      3
# 84                    local_bc_s1.tar  local_rho090_s1      3
# 85                    local_bc_s1.tar  local_rho090_s1      3
# 86                    local_bc_s1.tar  local_rho090_s1      3
# 93                    local_bc_s2.tar  local_rho090_s2      1
# 94                    local_bc_s2.tar  local_rho090_s2      1
# 95                    local_bc_s2.tar  local_rho090_s2      1
# 90                    local_bc_s2.tar  local_rho090_s2      1
# 91                    local_bc_s2.tar  local_rho090_s2      1
# 92                    local_bc_s2.tar  local_rho090_s2      1
# 99                    local_bc_s2.tar  local_rho090_s2      2
# 100                   local_bc_s2.tar  local_rho090_s2      2
# 101                   local_bc_s2.tar  local_rho090_s2      2
# 96                    local_bc_s2.tar  local_rho090_s2      2
# 97                    local_bc_s2.tar  local_rho090_s2      2
# 98                    local_bc_s2.tar  local_rho090_s2      2
# 105                   local_bc_s2.tar  local_rho090_s2      3
# 106                   local_bc_s2.tar  local_rho090_s2      3
# 107                   local_bc_s2.tar  local_rho090_s2      3
# 102                   local_bc_s2.tar  local_rho090_s2      3
# 103                   local_bc_s2.tar  local_rho090_s2      3
# 104                   local_bc_s2.tar  local_rho090_s2      3
#
#      optimizer_steps  phase    agent          n      loss  action_loss  \
# 3               4125   eval  agent_0   195056.0       NaN          NaN
# 4               4125   eval  agent_1   195056.0       NaN          NaN
# 5               4125   eval  agent_2   195056.0       NaN          NaN
# 0               4125  train  agent_0  5632000.0  0.326651     0.300402
# 1               4125  train  agent_1  5632000.0  0.311548     0.281544
# 2               4125  train  agent_2  5632000.0  0.244989     0.217602
# 9               8250   eval  agent_0   195056.0       NaN          NaN
# 10              8250   eval  agent_1   195056.0       NaN          NaN
# 11              8250   eval  agent_2   195056.0       NaN          NaN
# 6               8250  train  agent_0  5632000.0  0.206673     0.189332
# 7               8250  train  agent_1  5632000.0  0.195448     0.175387
# 8               8250  train  agent_2  5632000.0  0.147886     0.131116
# 15             12375   eval  agent_0   195056.0       NaN          NaN
# 16             12375   eval  agent_1   195056.0       NaN          NaN
# 17             12375   eval  agent_2   195056.0       NaN          NaN
# 12             12375  train  agent_0  5632000.0  0.179548     0.163632
# 13             12375  train  agent_1  5632000.0  0.167605     0.149830
# 14             12375  train  agent_2  5632000.0  0.124686     0.110332
# 21              4998   eval  agent_0   195056.0       NaN          NaN
# 22              4998   eval  agent_1   195056.0       NaN          NaN
# 23              4998   eval  agent_2   195056.0       NaN          NaN
# 18              4998  train  agent_0  6823936.0  0.163338     0.145819
# 19              4998  train  agent_1  6823936.0  0.287042     0.260609
# 20              4998  train  agent_2  6823936.0  0.179885     0.160062
# 27              9996   eval  agent_0   195056.0       NaN          NaN
# 28              9996   eval  agent_1   195056.0       NaN          NaN
# 29              9996   eval  agent_2   195056.0       NaN          NaN
# 24              9996  train  agent_0  6823936.0  0.078888     0.070625
# 25              9996  train  agent_1  6823936.0  0.156322     0.141458
# 26              9996  train  agent_2  6823936.0  0.109976     0.097449
# 33             14994   eval  agent_0   195056.0       NaN          NaN
# 34             14994   eval  agent_1   195056.0       NaN          NaN
# 35             14994   eval  agent_2   195056.0       NaN          NaN
# 30             14994  train  agent_0  6823936.0  0.066342     0.059204
# 31             14994  train  agent_1  6823936.0  0.127900     0.115415
# 32             14994  train  agent_2  6823936.0  0.093116     0.082268
# 39              4539   eval  agent_0   195056.0       NaN          NaN
# 40              4539   eval  agent_1   195056.0       NaN          NaN
# 41              4539   eval  agent_2   195056.0       NaN          NaN
# 36              4539  train  agent_0  6197248.0  0.156492     0.144517
# 37              4539  train  agent_1  6197248.0  0.236748     0.211342
# 38              4539  train  agent_2  6197248.0  0.243319     0.217667
# 45              9078   eval  agent_0   195056.0       NaN          NaN
# 46              9078   eval  agent_1   195056.0       NaN          NaN
# 47              9078   eval  agent_2   195056.0       NaN          NaN
# 42              9078  train  agent_0  6197248.0  0.090321     0.083926
# 43              9078  train  agent_1  6197248.0  0.163637     0.145520
# 44              9078  train  agent_2  6197248.0  0.146047     0.130710
# 51             13617   eval  agent_0   195056.0       NaN          NaN
# 52             13617   eval  agent_1   195056.0       NaN          NaN
# 53             13617   eval  agent_2   195056.0       NaN          NaN
# 48             13617  train  agent_0  6197248.0  0.076567     0.070860
# 49             13617  train  agent_1  6197248.0  0.146786     0.130182
# 50             13617  train  agent_2  6197248.0  0.123301     0.110247
# 57              4125   eval  agent_0   195056.0       NaN          NaN
# 58              4125   eval  agent_1   195056.0       NaN          NaN
# 59              4125   eval  agent_2   195056.0       NaN          NaN
# 54              4125  train  agent_0  5632000.0  0.852369     0.779735
# 55              4125  train  agent_1  5632000.0  0.666989     0.585829
# 56              4125  train  agent_2  5632000.0  0.473188     0.400553
# 63              8250   eval  agent_0   195056.0       NaN          NaN
# 64              8250   eval  agent_1   195056.0       NaN          NaN
# 65              8250   eval  agent_2   195056.0       NaN          NaN
# 60              8250  train  agent_0  5632000.0  0.516287     0.469252
# 61              8250  train  agent_1  5632000.0  0.394255     0.338103
# 62              8250  train  agent_2  5632000.0  0.276565     0.232027
# 69             12375   eval  agent_0   195056.0       NaN          NaN
# 70             12375   eval  agent_1   195056.0       NaN          NaN
# 71             12375   eval  agent_2   195056.0       NaN          NaN
# 66             12375  train  agent_0  5632000.0  0.429136     0.387038
# 67             12375  train  agent_1  5632000.0  0.329811     0.280898
# 68             12375  train  agent_2  5632000.0  0.231962     0.193559
# 75              4998   eval  agent_0   195056.0       NaN          NaN
# 76              4998   eval  agent_1   195056.0       NaN          NaN
# 77              4998   eval  agent_2   195056.0       NaN          NaN
# 72              4998  train  agent_0  6823936.0  0.326161     0.286384
# 73              4998  train  agent_1  6823936.0  0.787006     0.709052
# 74              4998  train  agent_2  6823936.0  0.373576     0.321136
# 81              9996   eval  agent_0   195056.0       NaN          NaN
# 82              9996   eval  agent_1   195056.0       NaN          NaN
# 83              9996   eval  agent_2   195056.0       NaN          NaN
# 78              9996  train  agent_0  6823936.0  0.167127     0.144890
# 79              9996  train  agent_1  6823936.0  0.412665     0.370592
# 80              9996  train  agent_2  6823936.0  0.219588     0.187087
# 87             14994   eval  agent_0   195056.0       NaN          NaN
# 88             14994   eval  agent_1   195056.0       NaN          NaN
# 89             14994   eval  agent_2   195056.0       NaN          NaN
# 84             14994  train  agent_0  6823936.0  0.137859     0.118196
# 85             14994  train  agent_1  6823936.0  0.388992     0.356041
# 86             14994  train  agent_2  6823936.0  0.182682     0.155002
# 93              4539   eval  agent_0   195056.0       NaN          NaN
# 94              4539   eval  agent_1   195056.0       NaN          NaN
# 95              4539   eval  agent_2   195056.0       NaN          NaN
# 90              4539  train  agent_0  6197248.0  0.487007     0.455954
# 91              4539  train  agent_1  6197248.0  0.498748     0.430020
# 92              4539  train  agent_2  6197248.0  0.518783     0.450184
# 99              9078   eval  agent_0   195056.0       NaN          NaN
# 100             9078   eval  agent_1   195056.0       NaN          NaN
# 101             9078   eval  agent_2   195056.0       NaN          NaN
# 96              9078  train  agent_0  6197248.0  0.300668     0.285743
# 97              9078  train  agent_1  6197248.0  0.348393     0.295723
# 98              9078  train  agent_2  6197248.0  0.322760     0.279930
# 105            13617   eval  agent_0   195056.0       NaN          NaN
# 106            13617   eval  agent_1   195056.0       NaN          NaN
# 107            13617   eval  agent_2   195056.0       NaN          NaN
# 102            13617  train  agent_0  6197248.0  0.217881     0.204556
# 103            13617  train  agent_1  6197248.0  0.309058     0.260643
# 104            13617  train  agent_2  6197248.0  0.273335     0.236994
#
#      aux_loss  accuracy  teacher_nonidle_frac  pred_nonidle_frac  \
# 3         NaN  0.975438              0.009208           0.032478
# 4         NaN  0.964087              0.102750           0.127938
# 5         NaN  0.965010              0.103468           0.129394
# 0    0.104997       NaN                   NaN                NaN
# 1    0.120015       NaN                   NaN                NaN
# 2    0.109548       NaN                   NaN                NaN
# 9         NaN  0.976571              0.009208           0.031622
# 10        NaN  0.973572              0.102750           0.117525
# 11        NaN  0.975535              0.103468           0.119099
# 6    0.069363       NaN                   NaN                NaN
# 7    0.080246       NaN                   NaN                NaN
# 8    0.067079       NaN                   NaN                NaN
# 15        NaN  0.977273              0.009208           0.031006
# 16        NaN  0.972526              0.102750           0.121570
# 17        NaN  0.978539              0.103468           0.117115
# 12   0.063664       NaN                   NaN                NaN
# 13   0.071100       NaN                   NaN                NaN
# 14   0.057416       NaN                   NaN                NaN
# 21        NaN  0.986368              0.019143           0.032129
# 22        NaN  0.978052              0.000308           0.022240
# 23        NaN  0.975479              0.021712           0.045136
# 18   0.070076       NaN                   NaN                NaN
# 19   0.105729       NaN                   NaN                NaN
# 20   0.079290       NaN                   NaN                NaN
# 27        NaN  0.989521              0.019143           0.029063
# 28        NaN  0.986501              0.000308           0.013796
# 29        NaN  0.981159              0.021712           0.039635
# 24   0.033050       NaN                   NaN                NaN
# 25   0.059458       NaN                   NaN                NaN
# 26   0.050106       NaN                   NaN                NaN
# 33        NaN  0.991638              0.019143           0.027095
# 34        NaN  0.987034              0.000308           0.013268
# 35        NaN  0.984410              0.021712           0.035723
# 30   0.028552       NaN                   NaN                NaN
# 31   0.049943       NaN                   NaN                NaN
# 32   0.043395       NaN                   NaN                NaN
# 39        NaN  0.995022              0.000164           0.005127
# 40        NaN  0.976079              0.011351           0.033934
# 41        NaN  0.978011              0.023352           0.042629
# 36   0.047903       NaN                   NaN                NaN
# 37   0.101625       NaN                   NaN                NaN
# 38   0.102608       NaN                   NaN                NaN
# 45        NaN  0.998211              0.000164           0.001923
# 46        NaN  0.973802              0.011351           0.036482
# 47        NaN  0.973813              0.023352           0.048079
# 42   0.025580       NaN                   NaN                NaN
# 43   0.072468       NaN                   NaN                NaN
# 44   0.061346       NaN                   NaN                NaN
# 51        NaN  0.996088              0.000164           0.004060
# 52        NaN  0.977806              0.011351           0.032545
# 53        NaN  0.979590              0.023352           0.042198
# 48   0.022830       NaN                   NaN                NaN
# 49   0.066416       NaN                   NaN                NaN
# 50   0.052216       NaN                   NaN                NaN
# 57        NaN  0.935557              0.009208           0.072897
# 58        NaN  0.927093              0.102750           0.171315
# 59        NaN  0.933276              0.103468           0.167060
# 54   0.145267       NaN                   NaN                NaN
# 55   0.162320       NaN                   NaN                NaN
# 56   0.145271       NaN                   NaN                NaN
# 63        NaN  0.954018              0.009208           0.054656
# 64        NaN  0.939679              0.102750           0.159339
# 65        NaN  0.950271              0.103468           0.150547
# 60   0.094071       NaN                   NaN                NaN
# 61   0.112303       NaN                   NaN                NaN
# 62   0.089076       NaN                   NaN                NaN
# 69        NaN  0.953557              0.009208           0.055102
# 70        NaN  0.952649              0.102750           0.146327
# 71        NaN  0.955526              0.103468           0.145733
# 66   0.084197       NaN                   NaN                NaN
# 67   0.097827       NaN                   NaN                NaN
# 68   0.076807       NaN                   NaN                NaN
# 75        NaN  0.972695              0.019143           0.046187
# 76        NaN  0.963862              0.000308           0.036431
# 77        NaN  0.953188              0.021712           0.068032
# 72   0.079554       NaN                   NaN                NaN
# 73   0.155908       NaN                   NaN                NaN
# 74   0.104880       NaN                   NaN                NaN
# 81        NaN  0.983897              0.019143           0.034893
# 82        NaN  0.941837              0.000308           0.058470
# 83        NaN  0.972510              0.021712           0.048545
# 78   0.044473       NaN                   NaN                NaN
# 79   0.084147       NaN                   NaN                NaN
# 80   0.065002       NaN                   NaN                NaN
# 87        NaN  0.985353              0.019143           0.033437
# 88        NaN  0.986204              0.000308           0.014099
# 89        NaN  0.966866              0.021712           0.054425
# 84   0.039328       NaN                   NaN                NaN
# 85   0.065904       NaN                   NaN                NaN
# 86   0.055359       NaN                   NaN                NaN
# 93        NaN  0.995653              0.000164           0.004491
# 94        NaN  0.942868              0.011351           0.067898
# 95        NaN  0.953593              0.023352           0.068503
# 90   0.062106       NaN                   NaN                NaN
# 91   0.137456       NaN                   NaN                NaN
# 92   0.137199       NaN                   NaN                NaN
# 99        NaN  0.989090              0.000164           0.011069
# 100       NaN  0.944247              0.011351           0.066555
# 101       NaN  0.954311              0.023352           0.068191
# 96   0.029849       NaN                   NaN                NaN
# 97   0.105340       NaN                   NaN                NaN
# 98   0.085660       NaN                   NaN                NaN
# 105       NaN  0.996842              0.000164           0.003286
# 106       NaN  0.949635              0.011351           0.061193
# 107       NaN  0.958222              0.023352           0.064223
# 102  0.026650       NaN                   NaN                NaN
# 103  0.096830       NaN                   NaN                NaN
# 104  0.072682       NaN                   NaN                NaN
#
#      false_noop_rate  false_intervention_rate
# 3           0.070090                 0.023906
# 4           0.038217                 0.032611
# 5           0.037382                 0.033089
# 0                NaN                      NaN
# 1                NaN                      NaN
# 2                NaN                      NaN
# 9           0.054215                 0.022939
# 10          0.046669                 0.021855
# 11          0.038948                 0.021776
# 6                NaN                      NaN
# 7                NaN                      NaN
# 8                NaN                      NaN
# 15          0.040665                 0.022298
# 16          0.032704                 0.024786
# 17          0.034317                 0.019043
# 12               NaN                      NaN
# 13               NaN                      NaN
# 14               NaN                      NaN
# 21          0.010266                 0.013615
# 22          0.000000                 0.021946
# 23          0.027803                 0.024654
# 18               NaN                      NaN
# 19               NaN                      NaN
# 20               NaN                      NaN
# 27          0.009749                 0.010449
# 28          0.000000                 0.013497
# 29          0.025870                 0.018901
# 24               NaN                      NaN
# 25               NaN                      NaN
# 26               NaN                      NaN
# 33          0.006575                 0.008365
# 34          0.000000                 0.012969
# 35          0.054018                 0.015243
# 30               NaN                      NaN
# 31               NaN                      NaN
# 32               NaN                      NaN
# 39          0.007000                 0.004969
# 40          0.069354                 0.023587
# 41          0.084121                 0.021035
# 36               NaN                      NaN
# 37               NaN                      NaN
# 38               NaN                      NaN
# 45          0.038498                 0.001774
# 46          0.045223                 0.026065
# 47          0.021675                 0.025944
# 42               NaN                      NaN
# 43               NaN                      NaN
# 44               NaN                      NaN
# 51          0.007000                 0.003903
# 52          0.043176                 0.022054
# 53          0.024595                 0.019944
# 48               NaN                      NaN
# 49               NaN                      NaN
# 50               NaN                      NaN
# 57          0.024267                 0.064506
# 58          0.009888                 0.077783
# 59          0.008446                 0.072052
# 54               NaN                      NaN
# 55               NaN                      NaN
# 56               NaN                      NaN
# 63          0.022483                 0.046091
# 64          0.009929                 0.064463
# 65          0.007304                 0.053470
# 60               NaN                      NaN
# 61               NaN                      NaN
# 62               NaN                      NaN
# 69          0.023864                 0.046548
# 70          0.010116                 0.049919
# 71          0.006413                 0.047942
# 66               NaN                      NaN
# 67               NaN                      NaN
# 68               NaN                      NaN
# 75          0.001372                 0.027898
# 76          0.000000                 0.036145
# 77          0.007631                 0.048080
# 72               NaN                      NaN
# 73               NaN                      NaN
# 74               NaN                      NaN
# 81          0.005119                 0.016369
# 82          0.000000                 0.058194
# 83          0.014505                 0.028027
# 78               NaN                      NaN
# 79               NaN                      NaN
# 80               NaN                      NaN
# 87          0.004367                 0.014842
# 88          0.000000                 0.013800
# 89          0.005416                 0.033964
# 84               NaN                      NaN
# 85               NaN                      NaN
# 86               NaN                      NaN
# 93          0.027999                 0.004339
# 94          0.019638                 0.057735
# 95          0.016247                 0.046872
# 90               NaN                      NaN
# 91               NaN                      NaN
# 92               NaN                      NaN
# 99          0.000000                 0.010908
# 100         0.021752                 0.056376
# 101         0.007456                 0.046309
# 96               NaN                      NaN
# 97               NaN                      NaN
# 98               NaN                      NaN
# 105         0.038498                 0.003139
# 106         0.022126                 0.050924
# 107         0.006892                 0.042249
# 102              NaN                      NaN
# 103              NaN                      NaN
# 104              NaN                      NaN
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/comparison_dashboard_figures/student_bc_eval_accuracy.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/comparison_dashboard_figures/student_bc_eval_pred_nonidle_frac.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/comparison_dashboard_figures/student_bc_eval_false_noop_rate.html
# Saved: /Users/corentinplumet/Documents/RL_Marl2grid/Topology_Task/outputs/comparison_dashboard_figures/student_bc_eval_false_intervention_rate.html
# [Figure({
#      'data': [{'customdata': array([['local_rho090_s0', 4125],
#                                     ['local_rho090_s0', 8250],
#                                     ['local_rho090_s0', 12375]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s0.tar',
#                'line': {'color': '#636efa', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s0.tar',
#                'orientation': 'v',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x3',
#                'y': {'bdata': 'gVenYck27z8yK6l4EUDvPy+whm7SRe8/', 'dtype': 'f8'},
#                'yaxis': 'y3'},
#               {'customdata': array([['local_rho090_s0', 4125],
#                                     ['local_rho090_s0', 8250],
#                                     ['local_rho090_s0', 12375]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s0.tar',
#                'line': {'color': '#636efa', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s0.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x2',
#                'y': {'bdata': 'ODbWec3Z7j+O3GfSfyfvPy+W8IHuHu8/', 'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'customdata': array([['local_rho090_s0', 4125],
#                                     ['local_rho090_s0', 8250],
#                                     ['local_rho090_s0', 12375]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s0.tar',
#                'line': {'color': '#636efa', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s0.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': 'OHDgwFzh7j/NnAuplTfvPx6YzA8yUO8/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s1.tar',
#                'line': {'color': '#EF553B', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s1.tar',
#                'orientation': 'v',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x3',
#                'y': {'bdata': 'RWEYqVOQ7z+TiifbJ6rvP9Yavj2Au+8/', 'dtype': 'f8'},
#                'yaxis': 'y3'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s1.tar',
#                'line': {'color': '#EF553B', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s1.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x2',
#                'y': {'bdata': 'xb1tqjRM7z/yAE0za5HvP9bAP1zJle8/', 'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s1.tar',
#                'line': {'color': '#EF553B', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s1.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': 'VMXVZB837z/8phAZqGXvP1x3tJJIgO8/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s2.tar',
#                'line': {'color': '#00cc96', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s2.tar',
#                'orientation': 'v',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x3',
#                'y': {'bdata': 'zGevQTjX7z/BT5a2V/HvP5TnlJP03+8/', 'dtype': 'f8'},
#                'yaxis': 'y3'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s2.tar',
#                'line': {'color': '#00cc96', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s2.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x2',
#                'y': {'bdata': 'yXDbUgk87z9X7hakYynvP72Ui5cwSu8/', 'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s2.tar',
#                'line': {'color': '#00cc96', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s2.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': 'kzs1p95L7z/K/MYkeSnvP00GrCDOWO8/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'customdata': array([['local_rho090_s0', 4125],
#                                     ['local_rho090_s0', 8250],
#                                     ['local_rho090_s0', 12375]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s0.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s0.tar',
#                'line': {'color': '#ab63fa', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s0.tar',
#                'orientation': 'v',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x3',
#                'y': {'bdata': 'mQS7KhXw7T/O5JB0UYfuP/0ILNGJg+4/', 'dtype': 'f8'},
#                'yaxis': 'y3'},
#               {'customdata': array([['local_rho090_s0', 4125],
#                                     ['local_rho090_s0', 8250],
#                                     ['local_rho090_s0', 12375]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s0.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s0.tar',
#                'line': {'color': '#ab63fa', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s0.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x2',
#                'y': {'bdata': '0SK6YL6q7T92bE1n2RHuP/HQnssafO4/', 'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'customdata': array([['local_rho090_s0', 4125],
#                                     ['local_rho090_s0', 8250],
#                                     ['local_rho090_s0', 12375]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s0.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s0.tar',
#                'line': {'color': '#ab63fa', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s0.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': 'MVKKu2Td7T/Vi+MUnmjuP5lGYmiqk+4/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s1.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s1.tar',
#                'line': {'color': '#FFA15A', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s1.tar',
#                'orientation': 'v',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x3',
#                'y': {'bdata': 'sKgBT1Eg7z9GsTprFXzvP+8RFtsCiO8/', 'dtype': 'f8'},
#                'yaxis': 'y3'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s1.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s1.tar',
#                'line': {'color': '#FFA15A', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s1.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x2',
#                'y': {'bdata': 'ZVSTaPTX7j/MIhnNhyPuP9radpz7ju8/', 'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s1.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s1.tar',
#                'line': {'color': '#FFA15A', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s1.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': '9nmwtIOA7j97R8xAzh7vP6bYbc+Q8O4/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s2.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s2.tar',
#                'line': {'color': '#19d3f3', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s2.tar',
#                'orientation': 'v',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x3',
#                'y': {'bdata': '0kUdsmLc7z8G0SK6oKbvPzHedQ0h5u8/', 'dtype': 'f8'},
#                'yaxis': 'y3'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s2.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s2.tar',
#                'line': {'color': '#19d3f3', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s2.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x2',
#                'y': {'bdata': 'jD1T3Pgr7j+vGScGRTfuP7eU6uNoY+4/', 'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s2.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s2.tar',
#                'line': {'color': '#19d3f3', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s2.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': 'klXLE9WD7j/IQC1LtonuPx/IerfBqe4/', 'dtype': 'f8'},
#                'yaxis': 'y'}],
#      'layout': {'annotations': [{'font': {},
#                                  'showarrow': False,
#                                  'text': 'agent=agent_2',
#                                  'textangle': 90,
#                                  'x': 0.98,
#                                  'xanchor': 'left',
#                                  'xref': 'paper',
#                                  'y': 0.15666666666666665,
#                                  'yanchor': 'middle',
#                                  'yref': 'paper'},
#                                 {'font': {},
#                                  'showarrow': False,
#                                  'text': 'agent=agent_1',
#                                  'textangle': 90,
#                                  'x': 0.98,
#                                  'xanchor': 'left',
#                                  'xref': 'paper',
# ...
#                'name': 'local_bc_bal020_w3_aux025_s0.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': 'Me7iyhLxoD+UTMzqikyWP+tAN/UXgJM/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s1.tar',
#                'line': {'color': '#EF553B', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s1.tar',
#                'orientation': 'v',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x3',
#                'y': {'bdata': 'nZemSSziiz+poXOeZWaFP+GCJFbXIYE/', 'dtype': 'f8'},
#                'yaxis': 'y3'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s1.tar',
#                'line': {'color': '#EF553B', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s1.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x2',
#                'y': {'bdata': 'W/x5X/x4lj9gu7iXVaSLP9yfQftDj4o/', 'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s1.tar',
#                'line': {'color': '#EF553B', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s1.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': 'gVIc+tA+mT8vC7sQwVqTP42dZUHMN48/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s2.tar',
#                'line': {'color': '#00cc96', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s2.tar',
#                'orientation': 'v',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x3',
#                'y': {'bdata': 'm6fbdItadD/MZMQqlxJdP890Y4w8+G8/', 'dtype': 'f8'},
#                'yaxis': 'y3'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s2.tar',
#                'line': {'color': '#00cc96', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s2.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x2',
#                'y': {'bdata': 'CXcSMEUnmD9caC6ZrbCaP2N8De48lZY/', 'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_bal020_w3_' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_bal020_w3_aux025_s2.tar',
#                'line': {'color': '#00cc96', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_bal020_w3_aux025_s2.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': 'Cm2fzEaKlT/4IjrWA5GaP2qMLNBDbJQ/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'customdata': array([['local_rho090_s0', 4125],
#                                     ['local_rho090_s0', 8250],
#                                     ['local_rho090_s0', 12375]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s0.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s0.tar',
#                'line': {'color': '#ab63fa', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s0.tar',
#                'orientation': 'v',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x3',
#                'y': {'bdata': 'MXqHa3ODsD/lHAJgPJmnPyY5zVgf1ac/', 'dtype': 'f8'},
#                'yaxis': 'y3'},
#               {'customdata': array([['local_rho090_s0', 4125],
#                                     ['local_rho090_s0', 8250],
#                                     ['local_rho090_s0', 12375]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s0.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s0.tar',
#                'line': {'color': '#ab63fa', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s0.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x2',
#                'y': {'bdata': 'ikaLRZfpsz/XyPJxpICwP2Lx19oBj6k/', 'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'customdata': array([['local_rho090_s0', 4125],
#                                     ['local_rho090_s0', 8250],
#                                     ['local_rho090_s0', 12375]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s0.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s0.tar',
#                'line': {'color': '#ab63fa', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s0.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': 'fOc9+gZysj+m/bEZYmCrP0a253DTi6g/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s1.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s1.tar',
#                'line': {'color': '#FFA15A', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s1.tar',
#                'orientation': 'v',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x3',
#                'y': {'bdata': 'jFI900GRnD//4mnVKcOQP0A3d3G2ZY4/', 'dtype': 'f8'},
#                'yaxis': 'y3'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s1.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s1.tar',
#                'line': {'color': '#FFA15A', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s1.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x2',
#                'y': {'bdata': 'YXq9WJuBoj+u/zW5nsutP3z327MOQ4w/', 'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'customdata': array([['local_rho090_s1', 4998],
#                                     ['local_rho090_s1', 9996],
#                                     ['local_rho090_s1', 14994]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s1.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s1.tar',
#                'line': {'color': '#FFA15A', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s1.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': 'cR+1hgGeqD+QusIcFbOcP+Bic9y3Y6E/', 'dtype': 'f8'},
#                'yaxis': 'y'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s2.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s2.tar',
#                'line': {'color': '#19d3f3', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s2.tar',
#                'orientation': 'v',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x3',
#                'y': {'bdata': 'RmfSMEzFcT81jnf5DVeGP+MKEcgMtmk/', 'dtype': 'f8'},
#                'yaxis': 'y3'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s2.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s2.tar',
#                'line': {'color': '#19d3f3', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s2.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x2',
#                'y': {'bdata': 'wgHdB3+PrT+LoDj8Wt2sP+huO5izEqo/', 'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'customdata': array([['local_rho090_s2', 4539],
#                                     ['local_rho090_s2', 9078],
#                                     ['local_rho090_s2', 13617]], dtype=object),
#                'hovertemplate': ('checkpoint=local_bc_s2.tar<br>' ... '{customdata[1]}<extra></extra>'),
#                'legendgroup': 'local_bc_s2.tar',
#                'line': {'color': '#19d3f3', 'dash': 'solid'},
#                'marker': {'symbol': 'circle'},
#                'mode': 'lines+markers',
#                'name': 'local_bc_s2.tar',
#                'orientation': 'v',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': {'bdata': 'AQID', 'dtype': 'i1'},
#                'xaxis': 'x',
#                'y': {'bdata': 'l2aYto//pz8hrFiE1bWnP2iKteemoaU/', 'dtype': 'f8'},
#                'yaxis': 'y'}],
#      'layout': {'annotations': [{'font': {},
#                                  'showarrow': False,
#                                  'text': 'agent=agent_2',
#                                  'textangle': 90,
#                                  'x': 0.98,
#                                  'xanchor': 'left',
#                                  'xref': 'paper',
#                                  'y': 0.15666666666666665,
#                                  'yanchor': 'middle',
#                                  'yref': 'paper'},
#                                 {'font': {},
#                                  'showarrow': False,
#                                  'text': 'agent=agent_1',
#                                  'textangle': 90,
#                                  'x': 0.98,
#                                  'xanchor': 'left',
#                                  'xref': 'paper',
#                                  'y': 0.4999999999999999,
#                                  'yanchor': 'middle',
#                                  'yref': 'paper'},
#                                 {'font': {},
#                                  'showarrow': False,
#                                  'text': 'agent=agent_0',
#                                  'textangle': 90,
#                                  'x': 0.98,
#                                  'xanchor': 'left',
#                                  'xref': 'paper',
#                                  'y': 0.8433333333333332,
#                                  'yanchor': 'middle',
#                                  'yref': 'paper'}],
#                 'height': 820,
#                 'legend': {'title': {'text': 'checkpoint'}, 'tracegroupgap': 0},
#                 'template': '...',
#                 'title': {'text': 'Student BC eval false_intervention_rate'},
#                 'width': 1400,
#                 'xaxis': {'anchor': 'y', 'domain': [0.0, 0.98], 'title': {'text': 'epoch'}},
#                 'xaxis2': {'anchor': 'y2', 'domain': [0.0, 0.98], 'matches': 'x', 'showticklabels': False},
#                 'xaxis3': {'anchor': 'y3', 'domain': [0.0, 0.98], 'matches': 'x', 'showticklabels': False},
#                 'yaxis': {'anchor': 'x', 'domain': [0.0, 0.3133333333333333], 'title': {'text': 'false_intervention_rate'}},
#                 'yaxis2': {'anchor': 'x2',
#                            'domain': [0.34333333333333327, 0.6566666666666665],
#                            'title': {'text': 'false_intervention_rate'}},
#                 'yaxis3': {'anchor': 'x3',
#                            'domain': [0.6866666666666665, 0.9999999999999998],
#                            'title': {'text': 'false_intervention_rate'}}}
#  })]

# %% [markdown]
# ## Student Prediction vs Teacher Target
#
# This is the main sanity check after BC: does the student predict non-idle actions at the same rate as the teacher dataset, and is it missing rare non-idle actions?

# %%
if not student_epoch_df.empty and not dataset_agent_df.empty:
    latest_eval = (
        student_epoch_df[student_epoch_df["phase"].eq("eval")]
        .sort_values(["checkpoint", "agent", "epoch"])
        .groupby(["checkpoint", "agent"], dropna=False, observed=True)
        .tail(1)
        .copy()
    )

    checkpoint_meta_cols = [
        "checkpoint",
        "dataset",
        "balanced_nonidle_frac",
        "nonidle_weight",
        "aux_weight",
        "soft_distillation_loss",
        "soft_weight",
        "soft_temperature",
        "student_training_objective",
    ]
    checkpoint_meta_cols = [c for c in checkpoint_meta_cols if c in student_ckpt_df.columns]
    checkpoint_meta = student_ckpt_df[checkpoint_meta_cols].copy()
    if "dataset" in checkpoint_meta.columns:
        checkpoint_meta = checkpoint_meta.rename(columns={"dataset": "dataset_from_checkpoint"})

    latest_eval = latest_eval.merge(checkpoint_meta, on="checkpoint", how="left")
    if "dataset" not in latest_eval.columns:
        latest_eval["dataset"] = latest_eval.get("dataset_from_checkpoint")
    elif "dataset_from_checkpoint" in latest_eval.columns:
        latest_eval["dataset"] = latest_eval["dataset"].fillna(latest_eval["dataset_from_checkpoint"])
    latest_eval = latest_eval.drop(columns=["dataset_from_checkpoint"], errors="ignore")

    target = dataset_agent_df[["dataset", "agent"]].copy()
    if "teacher_nonidle_frac" in dataset_agent_df.columns:
        target["target_teacher_nonidle_frac"] = dataset_agent_df["teacher_nonidle_frac"]
    elif "teacher_action0_frac" in dataset_agent_df.columns:
        target["target_teacher_nonidle_frac"] = 1.0 - dataset_agent_df["teacher_action0_frac"]
    if "teacher_action0_frac" in dataset_agent_df.columns:
        target["target_teacher_action0_frac"] = dataset_agent_df["teacher_action0_frac"]
    if "was_overwritten_frac" in dataset_agent_df.columns:
        target["target_was_overwritten_frac"] = dataset_agent_df["was_overwritten_frac"]

    comparison = latest_eval.merge(target, on=["dataset", "agent"], how="left")
    if "teacher_nonidle_frac" in comparison.columns and "target_teacher_nonidle_frac" in comparison.columns:
        comparison["teacher_nonidle_frac"] = comparison["target_teacher_nonidle_frac"].fillna(comparison["teacher_nonidle_frac"])
    elif "target_teacher_nonidle_frac" in comparison.columns:
        comparison["teacher_nonidle_frac"] = comparison["target_teacher_nonidle_frac"]
    if "target_teacher_action0_frac" in comparison.columns:
        comparison["teacher_action0_frac"] = comparison["target_teacher_action0_frac"]
    if "target_was_overwritten_frac" in comparison.columns:
        comparison["was_overwritten_frac"] = comparison["target_was_overwritten_frac"]

    comparison["pred_minus_teacher_nonidle"] = comparison["pred_nonidle_frac"] - comparison["teacher_nonidle_frac"]
    display_columns = [
        "checkpoint", "dataset", "agent", "epoch", "accuracy", "pred_nonidle_frac",
        "teacher_nonidle_frac", "pred_minus_teacher_nonidle", "false_noop_rate",
        "false_intervention_rate", "balanced_nonidle_frac", "nonidle_weight", "aux_weight",
        "soft_distillation_loss", "soft_weight", "soft_temperature",
    ]
    display(comparison[[c for c in display_columns if c in comparison.columns]].sort_values(["checkpoint", "agent"]))

    import plotly.express as px
    fig = px.scatter(
        comparison,
        x="teacher_nonidle_frac",
        y="pred_nonidle_frac",
        color="checkpoint",
        symbol="agent",
        hover_data=[c for c in ["accuracy", "false_noop_rate", "false_intervention_rate", "pred_minus_teacher_nonidle"] if c in comparison.columns],
        title="Student predicted non-idle rate vs teacher dataset non-idle target",
        labels={"teacher_nonidle_frac": "teacher non-idle fraction", "pred_nonidle_frac": "student predicted non-idle fraction"},
    )
    fig.add_shape(type="line", x0=0, y0=0, x1=1, y1=1, line={"dash": "dash", "color": "black"})
    fig.update_layout(template="plotly_white", height=650, width=1050)
    cd.save_fig(fig, "teacher_student_pred_nonidle_vs_teacher_target", save=SAVE_FIGURES)
    if SHOW_FIGURES:
        fig.show()

    fig2 = px.bar(
        comparison,
        x="checkpoint",
        y="pred_minus_teacher_nonidle",
        color="agent",
        barmode="group",
        hover_data=[c for c in ["dataset", "teacher_nonidle_frac", "pred_nonidle_frac"] if c in comparison.columns],
        title="Student non-idle bias relative to teacher target",
    )
    fig2.update_layout(template="plotly_white", height=620, width=1250)
    fig2.update_xaxes(tickangle=-30)
    cd.save_fig(fig2, "teacher_student_nonidle_bias_by_agent", save=SAVE_FIGURES)
    if SHOW_FIGURES:
        fig2.show()
else:
    print("Need both student checkpoint metrics and dataset summaries for this comparison.")

# %% [markdown]
# ## Standalone Full-Test Eval Of Student Checkpoints
#
# Run full-test evals with `--eval-action-heuristic none`, then this cell will pick up the JSON summaries.

# %%
full_test = cd.load_full_test_results()
if not full_test.empty:
    student_full_test = full_test[
        full_test["checkpoint"].astype(str).str.contains("teacher_student", case=False, na=False)
        | full_test["run_like"].astype(str).str.contains("bc|student|teacher", case=False, na=False)
    ].copy()
else:
    student_full_test = full_test

display(student_full_test.sort_values("survival_percent", ascending=False) if not student_full_test.empty else student_full_test)
cd.plot_full_test_results(student_full_test, show=SHOW_FIGURES, save=SAVE_FIGURES)

# %% [markdown]
# ## Export Teacher-Student Tables

# %%
out_dir = cd.FIG_DIR
out_dir.mkdir(parents=True, exist_ok=True)
if not dataset_df.empty:
    dataset_df.to_csv(out_dir / "teacher_student_dataset_summary.csv", index=False)
if not dataset_agent_df.empty:
    dataset_agent_df.to_csv(out_dir / "teacher_student_dataset_agent_summary.csv", index=False)
if not student_ckpt_df.empty:
    student_ckpt_df.to_csv(out_dir / "teacher_student_checkpoint_summary.csv", index=False)
if not student_epoch_df.empty:
    student_epoch_df.to_csv(out_dir / "teacher_student_epoch_metrics.csv", index=False)
if not student_full_test.empty:
    student_full_test.to_csv(out_dir / "teacher_student_full_test_results.csv", index=False)
print("Wrote CSV summaries to", out_dir)
